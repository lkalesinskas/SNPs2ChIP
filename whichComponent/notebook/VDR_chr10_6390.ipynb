# %% [markdown]
# ## VDR chr10_6390 example -- Which component is important?
#
# - The specific context of this variant and disease is described in this google doc:
#   - https://docs.google.com/document/d/16GuSasXWX-5qwvKAX5-4VxtrbmsIu9UgrP311_viqQc/edit?usp=sharing
# - This notebook would show,
#   1. Given the SNP, identify which genomic bin contains the SNP
#   1. Use genomic bin squared cosine score to find the top 3 important components for the genomic bin
#   1. Investigate the top component for the genomic bins
#     - Use assay contribution scores to see what assays are important for the component
#     - Use genomic bin contribution scores to see what other gnomic bins are important for the component
#     - Explorer the results of enrichment analysis

# %%
% matplotlib inline

import numpy as np
import pandas as pd
import matplotlib, collections, itertools, os, re, textwrap, logging, sys
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
from functools import reduce

from logging.config import dictConfig
from logging import getLogger

dictConfig(dict(
    version = 1,
    formatters = {'f': {'format': '%(asctime)s %(name)-12s %(levelname)-8s %(message)s'}},
    handlers = {
        'h': {'class': 'logging.StreamHandler','formatter': 'f',
              'level': logging.DEBUG}},
    root = {'handlers': ['h'], 'level': logging.DEBUG,},
))

matplotlib.rc('font',**{'size':16, 'family':'sans-serif','sans-serif':['HelveticaNeue', 'Helvetica']})

logger = getLogger('notebook')

# %%
repo_dir=os.path.realpath(
    os.path.dirname(os.path.dirname(os.getcwd()))
)

# %%
data_dir=os.path.realpath(
    os.path.join(os.path.dirname(os.getcwd()), 'private_data')
)

# %%
enrichment_data_dir=os.path.join(repo_dir, 'enrichment', 'private_data')

# %%
sys.path.append(os.path.join(repo_dir, 'enrichment', 'src'))
from great import read_great_res_wrapper

# %%
metadata_dir=os.path.join(
    repo_dir, 'metadata'
)
metadata = pd.read_table(
    os.path.join(metadata_dir, 'sample_antibody_map_v2_with_metadata.tsv'),
    sep='\t',
)

# %% [markdown]
# ### Step 1: SNP to genomic bin

# %%
genomic_bin_df=pd.read_csv(
    os.path.join(repo_dir, 'enrichment', 'private_data', 'loci_def.bed'),
    names=['chr', 'chromStart', 'chromEnd', 'name'],
    sep='\t'
)

# %%
genomic_bin_df[genomic_bin_df['name'] == 'chr10_6390']
# Out:
#           chr  chromStart  chromEnd        name
# 216060  chr10     6390000   6391000  chr10_6390

# %% [markdown]
# This means the index of the genomic bin of our interest is 216060

# %%
genomic_bin_idx=216060

# %% [markdown]
# ### Step 2: Which component is important for a given genomic bin -- genomic bin squared cosine score
# - Let's write our decomposition as X = UDV' where X is input feature matrix, D is diagonal singular value matrix, U is left singular vector matrix (on assay space), V is right singular vector matrix (on genomic bin space), and `'` denotes the transposition of the matrix.
# - Genomic bin squared cosine score is defined as L2-normalized version of the matrix product (VD) so that any given slice for a given genomic bin has Euclidian norm of 1.
# - The interpretation of the score is it represents the relative importance of the component given a genomic bin.
# - More formal definition:
#   - https://docs.google.com/document/d/1YRuaIvHvjb_6SJwlml1dQDegiGlGbdfz_zN-5bneroE/edit?usp=sharing

# %% [markdown]
# #### read the decomposed matrices

# %%
def read_decomposed_matrix(filename, compression=None):
    if((compression is None) and (len(filename) > 3) and (filename[-3:] == '.gz')):
        compression='gzip'
    df = pd.read_csv(
        os.path.join(data_dir, filename),
        compression=compression
    )
    mat = df.iloc[:, 1:].as_matrix()
    idx = df.iloc[:, 0].as_matrix()
    return mat, idx

# %%
d_mat_temp, d_idx = read_decomposed_matrix(os.path.join(data_dir, 'diagonalScore.csv.gz'))
d_vec = d_mat_temp[:, 0]

# %%
u_mat, u_idx = read_decomposed_matrix(os.path.join(data_dir, 'uScore.csv.gz'))

# %%
v_mat, v_idx = read_decomposed_matrix(os.path.join(data_dir, 'vScore.csv.gz'))

# %%
d_vec.shape, u_mat.shape, v_mat.shape, d_idx.shape, u_idx.shape, v_idx.shape
# Out:
# ((652,), (652, 652), (379541, 652), (652,), (652,), (379541,))

# %% [markdown]
# #### compute matrix products, UD and VD

# %%
u_dot_d = np.dot(u_mat, np.diag(d_vec))

# %%
v_dot_d = np.dot(v_mat, np.diag(d_vec))

# %%
u_dot_d.shape, v_dot_d.shape
# Out:
# ((652, 652), (379541, 652))

# %% [markdown]
# #### compute normalized matrices
# - v_dot_d_find_pcs: genomic bin --> which PC? genomic bin squared contribution score.
# - u_dot_d_fine_pcs: assay       --> which PC? assay squared contribution score.
# - v_dot_d_find_loci: PC --> which genomic bins? genomic bin contribution score.
# - u_dot_d_find_assay: PC --> which assay? assay contribution score

# %%
v_dot_d_find_pcs = (v_dot_d ** 2 ) / (np.sum(v_dot_d ** 2, axis = 1)[:,np.newaxis])

# %%
u_dot_d_find_pcs = (u_dot_d ** 2 ) / (np.sum(u_dot_d ** 2, axis = 1)[:,np.newaxis])

# %%
v_dot_d_find_loci = (v_dot_d ** 2 ) / (np.sum(v_dot_d ** 2, axis = 0)[np.newaxis, :])

# %%
u_dot_d_find_assay = (u_dot_d ** 2 ) / (np.sum(u_dot_d ** 2, axis = 0)[np.newaxis, :])

# %% [markdown]
# #### let's identify the top 3 important components for the genomic bin chr17_38023 (index: 328517)

# %%
np.argsort(-v_dot_d_find_pcs[genomic_bin_idx, :])[:5]
# Out:
# array([ 5,  1, 73, 14,  2])

# %%
v_dot_d_find_pcs[genomic_bin_idx, np.argsort(-v_dot_d_find_pcs[genomic_bin_idx, :])[:5]]
# Out:
# array([0.10332161, 0.04327748, 0.03535886, 0.02969716, 0.02020912])

# %% [markdown]
# This means PC5 (0-based index) is the most important component for this bin with 10.3% of squared cosine score, PC1 is the second important one with 4.3%, etc ...

# %% [markdown]
# ### Step 3: investigation of the components

# %% [markdown]
# #### PC5 (the top component)
#
# We will investigate
#
# 1. What assays are driving this component?
# 1. What genomic loci are driving this component?
# 1.  What are the top hits in the enrichment analysis?

# %%
component_idx=5

# %% [markdown]
# #### what assays are driving this component?

# %%
np.argsort(-u_dot_d_find_assay[:, component_idx])[:5]
# Out:
# array([188, 433,  76, 434, 431])

# %%
u_dot_d_find_assay[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], component_idx]
# Out:
# array([0.1195496 , 0.08228496, 0.05328201, 0.03843322, 0.03278715])

# %%
metadata.iloc[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], :]
# Out:
#     sample_number antibody Genome assembly   Antigen class       Antigen  \
# 188    SRX1027619      NaN            hg19  No description           NaN
# 433     SRX651491      NaN            hg19         Histone       H3K4me3
# 76      ERX329687      NaN            hg19    Unclassified  Unclassified
# 434     SRX651492      NaN            hg19         Histone       H3K4me1
# 431     SRX651470      NaN            hg19         Histone       H3K4me3
#
#     Cell type class                 Cell type  \
# 188           Blood  Lymphoblastoid cell line
# 433           Blood  Lymphoblastoid cell line
# 76            Blood  Lymphoblastoid cell line
# 434           Blood  Lymphoblastoid cell line
# 431           Blood  Lymphoblastoid cell line
#
#                                  Cell type description  \
# 188  Tissue=blood|Lineage=mesoderm|Description=pare...
# 433  Tissue=blood|Lineage=mesoderm|Description=pare...
# 76   Tissue=blood|Lineage=mesoderm|Description=pare...
# 434  Tissue=blood|Lineage=mesoderm|Description=pare...
# 431  Tissue=blood|Lineage=mesoderm|Description=pare...
#
#                 Processing logs  \
# 188  804451442,97.3,44.1,118575
# 433    166047212,93.9,6.4,63296
# 76   238094924,94.2,33.9,144042
# 434   112405175,94.2,1.6,121976
# 431    117212731,95.4,4.0,47422
#
#                                                  Title  \
# 188                  ChIP-seq of Homo sapiens: H3K4me3
# 433  GSM1435515: LCL19238 H3K4me3; Homo sapiens; Ch...
# 76   Illumina HiSeq 2000 sequencing; Coordinated ef...
# 434  GSM1435516: LCL19239 H3K4me1; Homo sapiens; Ch...
# 431  GSM1435517: LCL19239 H3K4me3; Homo sapiens; Ch...
#
#               ...           age  treatment genotype lab  age.1 health state  \
# 188           ...           NaN        NaN      NaN NaN    NaN          NaN
# 433           ...           NaN        NaN      NaN NaN    NaN          NaN
# 76            ...           NaN        NaN      NaN NaN    NaN          NaN
# 434           ...           NaN        NaN      NaN NaN    NaN          NaN
# 431           ...           NaN        NaN      NaN NaN    NaN          NaN
#
#      cell_type  tissue_type  provider                     sex
# 188       LCLs        blood   Coriell  pooled male and female
# 433        NaN          NaN       NaN                     NaN
# 76     NA12878          NaN       NaN                  female
# 434        NaN          NaN       NaN                     NaN
# 431        NaN          NaN       NaN                     NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# #### what genomic bins are driving this component?

# %%
np.argsort(-v_dot_d_find_loci[:, component_idx])[:5]
# Out:
# array([282969, 130825, 187463, 337732, 233484])

# %%
v_dot_d_find_loci[np.argsort(-v_dot_d_find_loci[:, component_idx])[:5], component_idx]
# Out:
# array([8.04405926e-05, 6.46164381e-05, 6.45142013e-05, 6.39899652e-05,
#        6.37951179e-05])

# %% [markdown]
# These genomic bins are important for the PC. Note the genomic bin contribution scores are very small compared to assay contribution score. This is expected becasue of the large number of genomic bins in the whole-genome analysis.

# %% [markdown]
# #### where is our loci of interest in this ranking?

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[
    genomic_bin_idx, component_idx])
# Out:
# 18420

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[
    genomic_bin_idx, component_idx]) / v_dot_d_find_loci.shape[0]
# Out:
# 0.04853230612766473

# %% [markdown]
# It's roughly on the top 5 percentile.

# %% [markdown]
# #### results of the enrichment analysis

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'HumanPhenotypeOntology').head(10)
# Out:
#           # ID                                 Desc         BPval     BFold
# 0   HP:0002697                    Parietal foramina  4.367679e-08  2.372433
# 1   HP:0004425                        Flat forehead  1.568965e-06  2.735910
# 3   HP:0004442            Sagittal craniosynostosis  2.359962e-06  2.733096
# 4   HP:0002365          Hypoplasia of the brainstem  2.396735e-06  2.031767
# 5   HP:0010054  Abnormality of the first metatarsal  2.506458e-06  2.574793
# 7   HP:0006191                   Deep palmar crease  4.189624e-06  2.977180
# 8   HP:0000557                          Buphthalmos  4.706791e-06  2.287392
# 12  HP:0009836       Broad distal phalanx of finger  1.739019e-05  2.601329
# 18  HP:0003741        Congenital muscular dystrophy  3.098136e-05  2.094681
# 21  HP:0003535          3-Methylglutaconic aciduria  3.861840e-05  2.428799

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOBiologicalProcess').head(10)
# Out:
#            # ID                                               Desc     BPval  \
# 62   GO:0035089        establishment of apical/basal cell polarity  0.000008
# 76   GO:0075733                   intracellular transport of virus  0.000012
# 100  GO:0051775                            response to redox state  0.000021
# 108  GO:0061162           establishment of monopolar cell polarity  0.000025
# 113  GO:0070127  tRNA aminoacylation for mitochondrial protein ...  0.000027
# 116  GO:0071624      positive regulation of granulocyte chemotaxis  0.000029
# 126  GO:0090023       positive regulation of neutrophil chemotaxis  0.000034
# 148  GO:0018401  peptidyl-proline hydroxylation to 4-hydroxy-L-...  0.000056
# 161  GO:0001672    regulation of chromatin assembly or disassembly  0.000072
# 164  GO:0006999                          nuclear pore organization  0.000077
#
#         BFold
# 62   2.658500
# 76   2.073909
# 100  2.764178
# 108  2.320837
# 113  4.115960
# 116  2.016287
# 126  2.020100
# 148  2.373342
# 161  3.185283
# 164  2.528835

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenotype').head(10)
# Out:
#           # ID                                        Desc         BPval  \
# 12  MP:0001771        abnormal circulating magnesium level  1.832349e-07
# 19  MP:0003954     abnormal Reichert's membrane morphology  8.388949e-07
# 53  MP:0002348      abnormal lymph node medulla morphology  9.682417e-06
# 54  MP:0010092       increased circulating magnesium level  1.018919e-05
# 59  MP:0009545  abnormal dermis papillary layer morphology  1.604188e-05
# 60  MP:0010743                      delayed suture closure  1.697130e-05
# 65  MP:0001669                 abnormal glucose absorption  2.245532e-05
# 69  MP:0006210                         abnormal orbit size  2.804297e-05
# 77  MP:0002050                            pheochromocytoma  3.830129e-05
# 79  MP:0000666        decreased prostate gland duct number  4.319200e-05
#
#        BFold
# 12  2.327122
# 19  2.004437
# 53  2.903855
# 54  2.628006
# 59  2.274394
# 60  2.208579
# 65  2.618271
# 69  2.181630
# 77  2.589431
# 79  2.700373

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenoSingleKO').head(10)
# Out:
#           # ID                                        Desc         BPval  \
# 5   MP:0012129             failure of blastocyst formation  2.360537e-09
# 8   MP:0002663                  failure to form blastocele  3.603307e-09
# 23  MP:0003954     abnormal Reichert's membrane morphology  8.388949e-07
# 24  MP:0001771        abnormal circulating magnesium level  1.211860e-06
# 33  MP:0010743                      delayed suture closure  3.083532e-06
# 34  MP:0002050                            pheochromocytoma  3.483130e-06
# 44  MP:0002348      abnormal lymph node medulla morphology  9.682417e-06
# 48  MP:0009545  abnormal dermis papillary layer morphology  1.604188e-05
# 60  MP:0000275                           heart hyperplasia  4.592075e-05
# 69  MP:0002031     increased adrenal gland tumor incidence  6.052274e-05
#
#        BFold
# 5   2.005173
# 8   2.004262
# 23  2.004437
# 24  2.284786
# 33  2.694599
# 34  3.010810
# 44  2.903855
# 48  2.274394
# 60  2.012848
# 69  2.408676

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOCellularComponent').head(10)
# Out:
#           # ID                                               Desc     BPval  \
# 5   GO:0005606                                  laminin-1 complex  0.000001
# 7   GO:0043256                                    laminin complex  0.000005
# 21  GO:0019031                                     viral envelope  0.000610
# 48  GO:0031080                            nuclear pore outer ring  0.002727
# 54  GO:0005666            DNA-directed RNA polymerase III complex  0.004041
# 58  GO:0019908  nuclear cyclin-dependent protein kinase holoen...  0.004746
# 72  GO:0016461                      unconventional myosin complex  0.007764
# 81  GO:0005677                        chromatin silencing complex  0.010734
# 85  GO:0005736              DNA-directed RNA polymerase I complex  0.011807
# 93  GO:0005851  eukaryotic translation initiation factor 2B co...  0.014343
#
#        BFold
# 5   2.325389
# 7   2.148635
# 21  2.839336
# 48  2.255517
# 54  2.228519
# 58  2.188418
# 72  2.067299
# 81  2.111160
# 85  2.494752
# 93  2.793472

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOMolecularFunction').head(10)
# Out:
#           # ID                                               Desc  \
# 3   GO:0043022                                   ribosome binding
# 11  GO:0031545            peptidyl-proline 4-dioxygenase activity
# 14  GO:0043208                          glycosphingolipid binding
# 30  GO:0001056                        RNA polymerase III activity
# 34  GO:0005007  fibroblast growth factor-activated receptor ac...
# 48  GO:0032407                          MutSalpha complex binding
# 60  GO:0015377                 cation:chloride symporter activity
# 65  GO:0047499      calcium-independent phospholipase A2 activity
# 69  GO:0032404                    mismatch repair complex binding
# 74  GO:0016421                           CoA carboxylase activity
#
#            BPval     BFold
# 3   7.584495e-08  2.351977
# 11  8.138740e-06  2.466700
# 14  2.462545e-05  2.495340
# 30  3.860479e-04  3.131341
# 34  5.214530e-04  2.250279
# 48  1.512241e-03  2.575431
# 60  2.143232e-03  2.088132
# 65  2.303207e-03  3.545742
# 69  2.498749e-03  2.155177
# 74  2.932712e-03  2.029746

# %% [markdown]
# #### PC1 (the second component)

# %%
component_idx=1

# %% [markdown]
# #### what assays are driving this component?

# %%
np.argsort(-u_dot_d_find_assay[:, component_idx])[:5]
# Out:
# array([  5, 434,  39, 181, 180])

# %%
u_dot_d_find_assay[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], component_idx]
# Out:
# array([0.25162818, 0.06753813, 0.06040728, 0.04239344, 0.04134171])

# %%
metadata.iloc[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], :]
# Out:
#     sample_number antibody Genome assembly   Antigen class       Antigen  \
# 5       ERX329616      NaN            hg19    Unclassified  Unclassified
# 434     SRX651492      NaN            hg19         Histone       H3K4me1
# 39      ERX329650      NaN            hg19    Unclassified  Unclassified
# 181    SRX1027612      NaN            hg19  No description           NaN
# 180    SRX1027611      NaN            hg19  No description           NaN
#
#     Cell type class                 Cell type  \
# 5             Blood  Lymphoblastoid cell line
# 434           Blood  Lymphoblastoid cell line
# 39            Blood  Lymphoblastoid cell line
# 181           Blood  Lymphoblastoid cell line
# 180           Blood  Lymphoblastoid cell line
#
#                                  Cell type description  \
# 5    Tissue=blood|Lineage=mesoderm|Description=pare...
# 434  Tissue=blood|Lineage=mesoderm|Description=pare...
# 39   Tissue=blood|Lineage=mesoderm|Description=pare...
# 181  Tissue=blood|Lineage=mesoderm|Description=pare...
# 180  Tissue=blood|Lineage=mesoderm|Description=pare...
#
#                Processing logs  \
# 5    176973882,81.5,56.2,35831
# 434  112405175,94.2,1.6,121976
# 39    159910142,78.7,57.6,7876
# 181  148497099,94.2,23.5,47476
# 180  132887926,94.3,21.5,45014
#
#                                                  Title  \
# 5    Illumina HiSeq 2000 sequencing; Coordinated ef...
# 434  GSM1435516: LCL19239 H3K4me1; Homo sapiens; Ch...
# 39   Illumina HiSeq 2000 sequencing; Coordinated ef...
# 181          ChIP-seq of Homo sapiens: NFkB-replicate2
# 180          ChIP-seq of Homo sapiens: NFkB-replicate1
#
#               ...           age  treatment genotype lab  age.1 health state  \
# 5             ...           NaN        NaN      NaN NaN    NaN          NaN
# 434           ...           NaN        NaN      NaN NaN    NaN          NaN
# 39            ...           NaN        NaN      NaN NaN    NaN          NaN
# 181           ...           NaN        NaN      NaN NaN    NaN          NaN
# 180           ...           NaN        NaN      NaN NaN    NaN          NaN
#
#      cell_type  tissue_type  provider                     sex
# 5      NA19238          NaN       NaN                  female
# 434        NaN          NaN       NaN                     NaN
# 39     NA19239          NaN       NaN                    male
# 181       LCLs        blood   Coriell  pooled male and female
# 180       LCLs        blood   Coriell  pooled male and female
#
# [5 rows x 24 columns]

# %% [markdown]
# #### what genomic bins are driving this component?

# %%
np.argsort(-v_dot_d_find_loci[:, component_idx])[:5]
# Out:
# array([ 85,  36,  40,  86, 546])

# %%
v_dot_d_find_loci[np.argsort(-v_dot_d_find_loci[:, component_idx])[:5], component_idx]
# Out:
# array([3.17653819e-05, 3.17653819e-05, 3.17653819e-05, 3.17653819e-05,
#        3.17653819e-05])

# %% [markdown]
# #### where is our loci of interest, chr17_38023 (index: 328517), in this ranking?

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[genomic_bin_idx, component_idx])
# Out:
# 98102

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[genomic_bin_idx, component_idx]) / v_dot_d_find_loci.shape[0]
# Out:
# 0.2584753689324737

# %% [markdown]
# It's roughly on the top 26 percentile.

# %% [markdown]
# #### results of the enrichment analysis

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'HumanPhenotypeOntology').head(10)
# Out:
#           # ID                                               Desc     BPval  \
# 0   HP:0004395                                       Malnutrition  0.000005
# 1   HP:0001718                                    Mitral stenosis  0.000063
# 2   HP:0001413                             Micronodular cirrhosis  0.000120
# 5   HP:0004333                             Bone-marrow foam cells  0.000345
# 6   HP:0003548  Subsarcolemmal accumulations of abnormally sha...  0.000527
# 8   HP:0001414                   Microvesicular hepatic steatosis  0.000632
# 12  HP:0004975           Erlenmeyer flask deformity of the femurs  0.001488
# 13  HP:0002725                       Systemic lupus erythematosus  0.001533
# 17  HP:0005938      Abnormal respiratory motile cilium morphology  0.002178
# 21  HP:0001618                                          Dysphonia  0.003317
#
#        BFold
# 0   5.321346
# 1   3.783898
# 2   2.821075
# 5   6.657703
# 6   6.137533
# 8   3.131675
# 12  3.197454
# 13  3.788696
# 17  3.267208
# 21  2.208404

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOBiologicalProcess').head(10)
# Out:
#           # ID                                               Desc  \
# 5   GO:0043901      negative regulation of multi-organism process
# 8   GO:0050830        defense response to Gram-positive bacterium
# 9   GO:0043374    CD8-positive, alpha-beta T cell differentiation
# 14  GO:0006572                         tyrosine catabolic process
# 17  GO:0002286      T cell activation involved in immune response
# 19  GO:0044130  negative regulation of growth of symbiont in host
# 28  GO:0060706  cell differentiation involved in embryonic pla...
# 30  GO:0032814       regulation of natural killer cell activation
# 31  GO:0035404                     histone-serine phosphorylation
# 32  GO:0051851  modification by host of symbiont morphology or...
#
#            BPval     BFold
# 5   1.318940e-07  2.168513
# 8   5.854487e-07  2.436218
# 9   7.974458e-07  2.954704
# 14  1.401399e-06  7.532955
# 17  3.720987e-06  2.339229
# 19  7.317285e-06  2.802184
# 28  3.461585e-05  2.245746
# 30  3.942309e-05  2.472078
# 31  4.352375e-05  3.327948
# 32  4.485152e-05  2.404710

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenotype').head(10)
# Out:
#            # ID                                               Desc  \
# 5    MP:0008552   abnormal circulating tumor necrosis factor level
# 25   MP:0006309             decreased retinal ganglion cell number
# 38   MP:0008553  increased circulating tumor necrosis factor level
# 40   MP:0008392              decreased primordial germ cell number
# 54   MP:0008554  decreased circulating tumor necrosis factor level
# 92   MP:0010819                                primary atelectasis
# 98   MP:0001499                         abnormal kindling response
# 101  MP:0000798                   abnormal frontal lobe morphology
# 111  MP:0008589           abnormal circulating interleukin-1 level
# 116  MP:0004725                 decreased platelet serotonin level
#
#             BPval     BFold
# 5    5.025154e-11  2.137410
# 25   1.466071e-07  2.196054
# 38   9.253086e-07  2.065763
# 40   1.079230e-06  2.054944
# 54   2.946674e-06  2.397094
# 92   2.198725e-05  2.336993
# 98   2.828631e-05  2.472546
# 101  3.656873e-05  2.807890
# 111  5.936768e-05  2.180550
# 116  6.703600e-05  2.304622

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenoSingleKO').head(10)
# Out:
#           # ID                                               Desc  \
# 16  MP:0008552   abnormal circulating tumor necrosis factor level
# 47  MP:0009788  increased susceptibility to bacterial infectio...
# 55  MP:0008554  decreased circulating tumor necrosis factor level
# 61  MP:0009321            increased histiocytic sarcoma incidence
# 75  MP:0006309             decreased retinal ganglion cell number
# 83  MP:0009615                          abnormal zinc homeostasis
# 86  MP:0004721         abnormal platelet dense granule morphology
# 88  MP:0008784                                 craniorachischisis
# 89  MP:0004725                 decreased platelet serotonin level
# 90  MP:0003452                  abnormal parotid gland morphology
#
#            BPval     BFold
# 16  6.418123e-08  2.067143
# 47  3.363712e-06  2.019205
# 55  7.000738e-06  2.367790
# 61  1.319572e-05  2.534863
# 75  3.783763e-05  2.174031
# 83  5.456382e-05  4.900227
# 86  7.445109e-05  2.124580
# 88  8.473798e-05  3.461900
# 89  8.569051e-05  2.310633
# 90  9.398743e-05  4.188730

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOCellularComponent').head(10)
# Out:
#           # ID                                          Desc     BPval  \
# 1   GO:0030125                         clathrin vesicle coat  0.000067
# 2   GO:0030934                            anchoring collagen  0.000224
# 5   GO:0005861                              troponin complex  0.000632
# 10  GO:0002199               zona pellucida receptor complex  0.001140
# 12  GO:0031932                                 TORC2 complex  0.001389
# 13  GO:0030122                          AP-2 adaptor complex  0.001467
# 15  GO:0005865                 striated muscle thin filament  0.001538
# 20  GO:0030014                              CCR4-NOT complex  0.002663
# 22  GO:0030130  clathrin coat of trans-Golgi network vesicle  0.004041
# 35  GO:0036379                                   myofilament  0.009111
#
#        BFold
# 1   2.552380
# 2   2.456392
# 5   7.499313
# 10  4.497283
# 12  3.227893
# 13  2.582954
# 15  2.682054
# 20  2.416343
# 22  2.774748
# 35  2.027585

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOMolecularFunction').head(10)
# Out:
#           # ID                                               Desc     BPval  \
# 4   GO:0016857  racemase and epimerase activity, acting on car...  0.000011
# 9   GO:0003810  protein-glutamine gamma-glutamyltransferase ac...  0.000161
# 12  GO:0005143                    interleukin-12 receptor binding  0.000570
# 13  GO:0016854                    racemase and epimerase activity  0.000614
# 14  GO:0005149                     interleukin-1 receptor binding  0.000650
# 15  GO:0005024  transforming growth factor beta-activated rece...  0.000709
# 16  GO:0004340                               glucokinase activity  0.000847
# 17  GO:0005536                                    glucose binding  0.000861
# 23  GO:0051010                       microtubule plus-end binding  0.001684
# 24  GO:0017153            sodium:dicarboxylate symporter activity  0.002042
#
#        BFold
# 4   4.864881
# 9   3.933715
# 12  3.378259
# 13  3.142031
# 14  3.576795
# 15  2.011484
# 16  4.737863
# 17  4.154994
# 23  2.450133
# 24  2.719939

# %% [markdown]
# #### PC73 (the thrird component)

# %%
component_idx=73

# %% [markdown]
# #### what assays are driving this component?

# %%
np.argsort(-u_dot_d_find_assay[:, component_idx])[:5]
# Out:
# array([433,  64, 443, 316, 317])

# %%
u_dot_d_find_assay[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], component_idx]
# Out:
# array([0.10426188, 0.09234196, 0.07100191, 0.06702174, 0.04706068])

# %%
metadata.iloc[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], :]
# Out:
#     sample_number antibody Genome assembly Antigen class       Antigen  \
# 433     SRX651491      NaN            hg19       Histone       H3K4me3
# 64      ERX329675      NaN            hg19  Unclassified  Unclassified
# 443     SRX651501      NaN            hg19       Histone       H3K4me1
# 316     SRX356721  h3k4me1            hg19       Histone       H3K4me1
# 317     SRX356722  h3k4me1            hg19       Histone       H3K4me1
#
#     Cell type class                 Cell type  \
# 433           Blood  Lymphoblastoid cell line
# 64            Blood  Lymphoblastoid cell line
# 443           Blood  Lymphoblastoid cell line
# 316           Blood  Lymphoblastoid cell line
# 317           Blood  Lymphoblastoid cell line
#
#                                  Cell type description  \
# 433  Tissue=blood|Lineage=mesoderm|Description=pare...
# 64   Tissue=blood|Lineage=mesoderm|Description=pare...
# 443  Tissue=blood|Lineage=mesoderm|Description=pare...
# 316  Tissue=blood|Lineage=mesoderm|Description=pare...
# 317  Tissue=blood|Lineage=mesoderm|Description=pare...
#
#                Processing logs  \
# 433   166047212,93.9,6.4,63296
# 64   241109952,88.2,48.3,80858
# 443    64570748,96.0,3.0,52838
# 316    34201660,98.3,4.5,70303
# 317    31838094,98.5,5.1,66804
#
#                                                  Title   ...   age  treatment  \
# 433  GSM1435515: LCL19238 H3K4me3; Homo sapiens; Ch...   ...   NaN        NaN
# 64   Illumina HiSeq 2000 sequencing; Coordinated ef...   ...   NaN        NaN
# 443  GSM1435526: LCL18507 H3K4me1; Homo sapiens; Ch...   ...   NaN        NaN
# 316  GSM1234153: GM2255 H3K4me1 1; Homo sapiens; Ch...   ...   NaN        NaN
# 317  GSM1234154: GM2255 H3K4me1 2; Homo sapiens; Ch...   ...   NaN        NaN
#
#     genotype lab  age.1 health state  cell_type  tissue_type  provider     sex
# 433      NaN NaN    NaN          NaN        NaN          NaN       NaN     NaN
# 64       NaN NaN    NaN          NaN    NA19238          NaN       NaN  female
# 443      NaN NaN    NaN          NaN        NaN          NaN       NaN     NaN
# 316      NaN NaN    NaN          NaN       2255          NaN       NaN     NaN
# 317      NaN NaN    NaN          NaN       2255          NaN       NaN     NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# #### what genomic bins are driving this component?

# %%
np.argsort(-v_dot_d_find_loci[:, component_idx])[:5]
# Out:
# array([217546, 236653, 236652, 279512,  88007])

# %%
v_dot_d_find_loci[np.argsort(-v_dot_d_find_loci[:, component_idx])[:5], component_idx]
# Out:
# array([0.00019616, 0.00019205, 0.00018801, 0.00018011, 0.00017978])

# %% [markdown]
# #### where is our loci of interest, chr17_38023 (index: 328517), in this ranking?

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[genomic_bin_idx, component_idx])
# Out:
# 4269

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[genomic_bin_idx, component_idx]) / v_dot_d_find_loci.shape[0]
# Out:
# 0.01124779668072751

# %% [markdown]
# It's roughly on the top 1 percentile.

# %% [markdown]
# #### results of the enrichment analysis

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'HumanPhenotypeOntology').head(10)
# Out:
#           # ID                                     Desc         BPval  \
# 0   HP:0001878                         Hemolytic anemia  1.126939e-07
# 1   HP:0006530           Interstitial pulmonary disease  4.196880e-07
# 2   HP:0002583                                  Colitis  1.441889e-06
# 3   HP:0004369                  Decreased purine levels  8.433215e-06
# 4   HP:0001271                           Polyneuropathy  1.031858e-05
# 5   HP:0002173                    Hypoglycemic seizures  1.224480e-05
# 6   HP:0011145                     Symptomatic seizures  1.431779e-05
# 7   HP:0003565  Elevated erythrocyte sedimentation rate  1.969673e-05
# 8   HP:0001241                   Capitate-hamate fusion  2.311056e-05
# 10  HP:0004429               Recurrent viral infections  3.450729e-05
#
#        BFold
# 0   2.501702
# 1   6.723312
# 2   4.406802
# 3   4.296864
# 4   2.744127
# 5   3.705253
# 6   3.486968
# 7   8.817717
# 8   7.126692
# 10  2.740296

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOBiologicalProcess').head(10)
# Out:
#           # ID                                               Desc  \
# 3   GO:0031348            negative regulation of defense response
# 8   GO:0050688            regulation of defense response to virus
# 13  GO:0050728       negative regulation of inflammatory response
# 15  GO:0042098                               T cell proliferation
# 23  GO:0042992  negative regulation of transcription factor im...
# 36  GO:0051081                       nuclear envelope disassembly
# 44  GO:0042347  negative regulation of NF-kappaB import into n...
# 45  GO:0015758                                  glucose transport
# 46  GO:0015749                           monosaccharide transport
# 47  GO:0008645                                   hexose transport
#
#            BPval     BFold
# 3   6.349153e-12  2.133784
# 8   5.176126e-11  2.644539
# 13  2.599648e-09  2.003923
# 15  5.820725e-09  2.501011
# 23  6.555921e-08  2.659193
# 36  4.336010e-07  2.499376
# 44  8.395360e-07  3.095003
# 45  1.050236e-06  2.122810
# 46  1.074040e-06  2.103554
# 47  1.207382e-06  2.112212

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenotype').head(10)
# Out:
#           # ID                                               Desc  \
# 35  MP:0008553  increased circulating tumor necrosis factor level
# 52  MP:0004800  decreased susceptibility to experimental autoi...
# 56  MP:0008180           abnormal marginal zone B cell morphology
# 64  MP:0008125                     abnormal dendritic cell number
# 68  MP:0008539        decreased susceptibility to induced colitis
# 70  MP:0008552   abnormal circulating tumor necrosis factor level
# 76  MP:0005070  impaired natural killer cell mediated cytotoxi...
# 83  MP:0008172              abnormal follicular B cell morphology
# 84  MP:0008182              decreased marginal zone B cell number
# 91  MP:0011719  abnormal natural killer cell mediated cytotoxi...
#
#            BPval     BFold
# 35  3.151759e-13  2.780833
# 52  5.017430e-11  2.319404
# 56  1.070690e-10  2.032751
# 64  1.146185e-09  2.171483
# 68  1.608991e-09  3.687543
# 70  2.006196e-09  2.074254
# 76  4.927415e-09  2.231583
# 83  1.126701e-08  2.043186
# 84  1.572002e-08  2.037115
# 91  2.592665e-08  2.105791

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenoSingleKO').head(10)
# Out:
#           # ID                                               Desc  \
# 41  MP:0010766                        abnormal NK cell physiology
# 47  MP:0008180           abnormal marginal zone B cell morphology
# 58  MP:0010878                   increased trabecular bone volume
# 63  MP:0011518                           abnormal cell chemotaxis
# 65  MP:0008125                     abnormal dendritic cell number
# 68  MP:0005461                 abnormal dendritic cell morphology
# 70  MP:0008182              decreased marginal zone B cell number
# 72  MP:0008539        decreased susceptibility to induced colitis
# 77  MP:0008553  increased circulating tumor necrosis factor level
# 81  MP:0002362           abnormal spleen marginal zone morphology
#
#            BPval     BFold
# 41  1.620638e-11  2.071812
# 47  8.623327e-11  2.402066
# 58  6.890306e-10  3.473976
# 63  1.659544e-09  2.005680
# 65  2.184636e-09  2.500405
# 68  3.749675e-09  2.134901
# 70  5.953468e-09  2.581715
# 72  7.460242e-09  3.970646
# 77  1.175295e-08  2.614738
# 81  1.743614e-08  2.042762

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOCellularComponent').head(10)
# Out:
#           # ID                                               Desc     BPval  \
# 7   GO:0031232      extrinsic to external side of plasma membrane  0.000041
# 15  GO:0042765                    GPI-anchor transamidase complex  0.000176
# 20  GO:0031931                                      TORC1 complex  0.000637
# 21  GO:0001533                                 cornified envelope  0.000724
# 22  GO:0042101                            T cell receptor complex  0.000914
# 25  GO:0002102                                           podosome  0.001429
# 26  GO:0005763              mitochondrial small ribosomal subunit  0.001595
# 33  GO:0005827                                  polar microtubule  0.003306
# 39  GO:0000307  cyclin-dependent protein kinase holoenzyme com...  0.006348
# 40  GO:0005680                         anaphase-promoting complex  0.006797
#
#        BFold
# 7   4.603166
# 15  6.187982
# 20  4.977601
# 21  2.416596
# 22  2.846063
# 25  2.162778
# 26  2.803861
# 33  3.711101
# 39  2.007279
# 40  2.436506

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOMolecularFunction').head(10)
# Out:
#           # ID                                               Desc  \
# 3   GO:0005086     ARF guanyl-nucleotide exchange factor activity
# 6   GO:0042608                            T cell receptor binding
# 10  GO:0004198  calcium-dependent cysteine-type endopeptidase ...
# 12  GO:0042834                              peptidoglycan binding
# 13  GO:0017112     Rab guanyl-nucleotide exchange factor activity
# 18  GO:0015038      glutathione disulfide oxidoreductase activity
# 19  GO:0003923                   GPI-anchor transamidase activity
# 21  GO:0050699                                  WW domain binding
# 24  GO:0004623                          phospholipase A2 activity
# 26  GO:0005072  transforming growth factor beta receptor, cyto...
#
#            BPval     BFold
# 3   6.820259e-08  3.116550
# 6   2.245745e-07  6.447217
# 10  8.887818e-06  3.326388
# 12  2.477201e-05  6.084970
# 13  3.772063e-05  2.478562
# 18  1.636602e-04  6.261373
# 19  1.757277e-04  6.187982
# 21  2.788431e-04  2.260392
# 24  4.727523e-04  2.509656
# 26  5.129675e-04  2.571396
