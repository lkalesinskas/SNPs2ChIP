# %% [markdown]
# # Import Packages and Read in Dataframes
#
# Files are taken directly from the ChIP-Atlas site.

# %%
import os,sys
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from meta_utils import *
from analysis_utils import *

antigen_df = pd.read_csv('chip_atlas_antigen_list.csv')
celltype_df = pd.read_csv('chip_atlas_celltype_list.csv')
file_df = pd.read_csv('chip_atlas_file_list.csv')
exp_df = pd.read_csv('chip_atlas_experiment_list.csv')#.set_index('Experimental ID').rename_axis(None)
#exp_df.to_pickle("./exp_df.pkl")

# %% [markdown]
# ## Extract Metadata from Experimental Dataframe
#
# Read in the experimental dataframe from ChIP-Atlas site and parse through the `Meta data` column to find entries not curated by ChIP-Atlas creators for each experiment.
#
# This results in a new dataframe `exp_meta_df` that is indexied by `exp_ID` and contains

# %%
new_df = exp_df
new_df = new_df.set_index('Experimental ID')

exp_list = []
for idx,row in new_df.iterrows():
    
    meta_dict = []
    try: 
        meta_list = row['Meta data'].strip().split('||')
        for att in meta_list: 
            tup = att.strip().split('=')
            if len(tup) == 1:
                tup = ['misc', str(tup[0])]
            elif len(tup) > 2:
                tup[1:] = [' '.join(tup[1:])]
            meta_dict.append(tuple(tup))
    
    # No Metadata Available
    except:
        pass
    
    meta_dict.append(('exp_ID', idx))        
    exp_list.append(dict(meta_dict))
    
exp_meta_df = pd.DataFrame(exp_list).set_index('exp_ID')

# %% [markdown]
# # Create Dataframe w/ Original Attributes and Parsed Attributes
#
# This will be saved as `full_exp_df`.

# %%
full_exp_df = exp_meta_df.join(exp_df)
full_exp_df.shape
# Out:
# (65499, 1369)

# %% [markdown]
# # Parse through Redundant Data in Metadata Field
#
#
# See `analysis_utils.py` for helper functions used. Metadata included descriptors that contain overlapping content. Went through manually to correct these and incorporate them into the same field for celltype, tissue type, biomaterial provider, and sex.

# %%
# Cell Types
relevant = ['cell-line','cell line','implated cell line/type',
            'derived cell line','cell  line','cell line background','cell_line', 'celll line',
            'host cell line','cell line/vendor','parental cell line', 'cell line/clone','cell lines','cell _line_name']
tissue = ['cell line sournce','cell line/type','cell line origin','cell line source','cell lineage','cell line type']

keys = ['cell','line']

print('Cell Type Reundancy')
cell_df = extract_meta_columns(keys, full_exp_df, col_name='cell_type', relevant=relevant)

# Tissue Types
relevant = ['tissue','tissue/cell','tissue source/type','tissue of origin',
            'tissue-type','tissue_type','tissue/cell type','tissue type','tissue source',
           'source tissue','tissue origin','tissues']

keys = ['tissue']

print('Tissue Type Reundancy')
tissue_df = extract_meta_columns(keys, full_exp_df, col_name='tissue_type', relevant=relevant)

# Biomaterial Provider
keys = ['provider']

relevant = ['biomaterial_provider','chip antibody provider','chip_antibody_provider',
            'antibody vendor/provider','sample_provider','antibody provider']

print('Provider Reundancy')
provider_df = extract_meta_columns(keys, full_exp_df, col_name='provider', relevant=relevant)

# Sex
keys = ['sex']
relevant = ['age and sex', 'age sex','sex','sex type','patient sex','cell sex']

print('Sex Redundancy')
sex_df = extract_meta_columns(keys, full_exp_df, col_name='sex', relevant=relevant)
# Out:
# Cell Type Reundancy
# Num multi-rows: 10
# Total experiments:  20012
# Tissue Type Reundancy
# Num multi-rows: 22
# Total experiments:  13814
# Provider Reundancy
# Num multi-rows: 4
# Total experiments:  4204
# Sex Redundancy
# Num multi-rows: 4
# Total experiments:  10082

# %% [markdown]
# ## Combine Parsed Redundant Attributes together into a final metadata dataframe
#
# This includes batch information, source of experiment, tissue, age, treatment, genotype, source lab, age, gender, and health state.

# %%
final_list = ['BATCH','source_name','tissue','age','treatment','genotype'
              ,'lab','age','Sex','gender','donor gender','health state']

final_df = full_exp_df[final_list]

val = pd.merge(final_df,cell_df,left_index=True, right_index=True, how='outer')
val = pd.merge(val,tissue_df,left_index=True, right_index=True, how='outer')
val = pd.merge(val,provider_df,left_index=True, right_index=True, how='outer')
final_df = pd.merge(val,sex_df,left_index=True, right_index=True, how='outer')
final_df = final_df.drop(['Sex','sex','gender','donor gender'],axis=1)
sex_df = combine_attributes(filter_attributes(final_df, ['sex','Sex','gender', 'donor gender']), combined_col_name = 'sex')

final_df = pd.merge(final_df,sex_df,left_index=True, right_index=True, how='outer')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/shankaraanand/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-0891ce90d711> in <module>()
#       9 final_df = pd.merge(val,sex_df,left_index=True, right_index=True, how='outer')
#      10 final_df = final_df.drop(['Sex','sex','gender','donor gender'],axis=1)
# ---> 11 sex_df = combine_attributes(filter_attributes(final_df, ['sex','Sex','gender', 'donor gender']), combined_col_name = 'sex')
#      12
#      13 final_df = pd.merge(final_df,sex_df,left_index=True, right_index=True, how='outer')
#
# /Users/shankaraanand/Google Drive/Stanford/Co-Term/Spring/BMI 212/bigtranscription/metadata/analysis_utils.py in filter_attributes(df, attributes)
#      11     for i,att in enumerate(attributes):
#      12         if i == 0:
# ---> 13             left_df = df[df[att].notnull()][att]
#      14         else:
#      15             right_df = df[df[att].notnull()][att]
#
# /Users/shankaraanand/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /Users/shankaraanand/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2069         result = self._constructor(self._data.get(key))
#    2070         if result.columns.is_unique:
# -> 2071             result = result[key]
#    2072
#    2073         return result
#
# /Users/shankaraanand/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /Users/shankaraanand/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /Users/shankaraanand/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /Users/shankaraanand/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/shankaraanand/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'sex'

# %%
save = False

if save: 
    final_df.to_pickle("./exp_metadata_df.pkl")
#     exp_meta_mat = final_df.values
#     exp_meta_X = final_df.index.values
#     exp_meta_Y = final_df.columns.values

# Output Attributes to a Text File
# with open("attributes.txt", 'w') as f:
#     f.write("\n".join(sorted(list(full_exp_df))))

# %%
# Out:
# 688  experiments found for:
#  H. sapiens  -->  Blood  -->  Lymphoblastoid cell line

# %%
# Out:
# ['BATCH',
#  'source_name',
#  'tissue',
#  'age',
#  'treatment',
#  'genotype',
#  'lab',
#  'age',
#  'Sex',
#  'gender',
#  'donor gender',
#  'health state',
#  'cell_type',
#  'tissue_type',
#  'provider',
#  'sex_x',
#  'sex_y']

# %%
cell_type = 'Monocytes-CD14+'

e1 = pd.read_pickle('exp_metadata_df.pkl')
fin = pd.merge(exp_df.set_index('Experimental ID'),e1,left_index=True, right_index=True, how='outer')

exp_list = get_experiment_list(cell_type=cell_type)
lympho_df = fin.loc[exp_list]
#lympho_df.to_csv('GM12878.csv')
lympho_df[lympho_df['Meta data'].str.contains("disease")]
# Out:
# 121  experiments found for:
#  H. sapiens  -->  Blood  -->  Monocytes-CD14+
#           Genome assembly  Antigen class        Antigen Cell type class  \
# SRX461539            hg19        Histone       H3K27me3           Blood
# SRX461540            hg19        Histone        H3K4me3           Blood
# SRX461541            hg19        Histone         H3K9ac           Blood
# SRX461542            hg19  Input control  Input control           Blood
# SRX461543            hg19        Histone       H3K27me3           Blood
# SRX461544            hg19        Histone        H3K4me3           Blood
# SRX461545            hg19        Histone         H3K9ac           Blood
# SRX461546            hg19  Input control  Input control           Blood
# SRX461547            hg19        Histone       H3K27me3           Blood
# SRX461548            hg19        Histone        H3K4me3           Blood
# SRX461549            hg19        Histone         H3K9ac           Blood
# SRX461550            hg19  Input control  Input control           Blood
# SRX461551            hg19        Histone       H3K27me3           Blood
# SRX461552            hg19        Histone        H3K4me3           Blood
# SRX461553            hg19        Histone         H3K9ac           Blood
# SRX461554            hg19  Input control  Input control           Blood
# SRX749790            hg19        Histone       H3K27me3           Blood
# SRX749791            hg19        Histone        H3K4me3           Blood
# SRX749792            hg19        Histone         H3K9ac           Blood
# SRX749793            hg19   Unclassified   Unclassified           Blood
# SRX749794            hg19        Histone       H3K27me3           Blood
# SRX749795            hg19        Histone        H3K4me3           Blood
# SRX749796            hg19        Histone         H3K9ac           Blood
# SRX749797            hg19   Unclassified   Unclassified           Blood
#
#                  Cell type                              Cell type description  \
# SRX461539  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461540  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461541  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461542  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461543  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461544  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461545  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461546  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461547  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461548  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461549  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461550  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461551  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461552  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461553  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX461554  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX749790  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX749791  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX749792  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX749793  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX749794  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX749795  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX749796  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
# SRX749797  Monocytes-CD14+  Tissue=monocytes|Lineage=mesoderm|Description=...
#
#                     Processing logs  \
# SRX461539    40033914,96.1,84.3,284
# SRX461540  56660855,97.0,83.9,27151
# SRX461541   57322386,89.8,88.9,1976
# SRX461542   37363754,98.2,44.4,2519
# SRX461543    49270540,89.2,72.3,920
# SRX461544  67680186,89.5,90.7,22502
# SRX461545    45011336,85.3,90.5,296
# SRX461546   53812444,97.7,12.6,1398
# SRX461547    54928877,89.4,88.7,697
# SRX461548  43890155,96.7,74.5,28511
# SRX461549   73519854,89.8,89.0,1392
# SRX461550  43349150,97.2,13.9,11218
# SRX461551   54712013,96.5,78.1,1105
# SRX461552  52405860,95.3,91.8,11378
# SRX461553   51815312,88.3,89.0,1091
# SRX461554   44731236,98.5,24.0,6827
# SRX749790    48952274,86.0,82.6,390
# SRX749791  52886794,93.1,80.7,25534
# SRX749792    25921632,76.9,83.6,319
# SRX749793   90001277,97.0,29.8,1825
# SRX749794   59515666,92.8,69.2,7116
# SRX749795  54466332,98.5,44.7,39843
# SRX749796  58480131,93.0,72.9,11002
# SRX749797    41905127,97.5,6.0,1229
#
#                                                        Title  \
# SRX461539  GSM1320312: ChIP-seq analysis of H3K27me3 in h...
# SRX461540  GSM1320313: ChIP-seq analysis of H3K4me3  in h...
# SRX461541  GSM1320314: ChIP-seq analysis of H3K9Ac  in hu...
# SRX461542  GSM1320315: Sequencing of input DNA from human...
# SRX461543  GSM1320316: ChIP-seq analysis of H3K27me3 in h...
# SRX461544  GSM1320317: ChIP-seq analysis of H3K4me3  in h...
# SRX461545  GSM1320318: ChIP-seq analysis of H3K9Ac  in hu...
# SRX461546  GSM1320319: Sequencing of input DNA from human...
# SRX461547  GSM1320320: ChIP-seq analysis of H3K27me3 in h...
# SRX461548  GSM1320321: ChIP-seq analysis of H3K4me3  in h...
# SRX461549  GSM1320322: ChIP-seq analysis of H3K9Ac  in hu...
# SRX461550  GSM1320323: Sequencing of input DNA from human...
# SRX461551  GSM1320324: ChIP-seq analysis of H3K27me3 in h...
# SRX461552  GSM1320325: ChIP-seq analysis of H3K4me3  in h...
# SRX461553  GSM1320326: ChIP-seq analysis of H3K9Ac  in hu...
# SRX461554  GSM1320327: Sequencing of input DNA from human...
# SRX749790  GSM1536033: ChIP-seq analysis of H3K27me3 in h...
# SRX749791  GSM1536034: ChIP-seq analysis of H3K4me3  in h...
# SRX749792  GSM1536035: ChIP-seq analysis of H3K9Ac  in hu...
# SRX749793  GSM1536036: Sequencing of input DNA from human...
# SRX749794  GSM1536037: ChIP-seq analysis of H3K27me3 in h...
# SRX749795  GSM1536038: ChIP-seq analysis of H3K4me3  in h...
# SRX749796  GSM1536039: ChIP-seq analysis of H3K9Ac  in hu...
# SRX749797  GSM1536040: Sequencing of input DNA from human...
#
#                                                    Meta data BATCH ...   age  \
# SRX461539  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461540  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461541  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461542  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461543  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461544  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461545  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461546  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461547  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461548  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461549  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461550  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461551  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461552  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461553  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX461554  source_name=CD14++ CD16- monocytes from blood ...   NaN ...   NaN
# SRX749790  source_name=CD14++ CD16- monocytes from patien...   NaN ...   NaN
# SRX749791  source_name=CD14++ CD16- monocytes from patien...   NaN ...   NaN
# SRX749792  source_name=CD14++ CD16- monocytes from patien...   NaN ...   NaN
# SRX749793  source_name=CD14++ CD16- monocytes from patien...   NaN ...   NaN
# SRX749794  source_name=CD14++ CD16- monocytes from patien...   NaN ...   NaN
# SRX749795  source_name=CD14++ CD16- monocytes from patien...   NaN ...   NaN
# SRX749796  source_name=CD14++ CD16- monocytes from patien...   NaN ...   NaN
# SRX749797  source_name=CD14++ CD16- monocytes from patien...   NaN ...   NaN
#
#           treatment genotype  lab  age health state cell_type tissue_type  \
# SRX461539       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461540       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461541       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461542       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461543       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461544       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461545       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461546       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461547       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461548       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461549       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461550       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461551       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461552       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461553       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX461554       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX749790       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX749791       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX749792       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX749793       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX749794       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX749795       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX749796       NaN      NaN  NaN  NaN          NaN       NaN         NaN
# SRX749797       NaN      NaN  NaN  NaN          NaN       NaN         NaN
#
#           provider  sex
# SRX461539      NaN  NaN
# SRX461540      NaN  NaN
# SRX461541      NaN  NaN
# SRX461542      NaN  NaN
# SRX461543      NaN  NaN
# SRX461544      NaN  NaN
# SRX461545      NaN  NaN
# SRX461546      NaN  NaN
# SRX461547      NaN  NaN
# SRX461548      NaN  NaN
# SRX461549      NaN  NaN
# SRX461550      NaN  NaN
# SRX461551      NaN  NaN
# SRX461552      NaN  NaN
# SRX461553      NaN  NaN
# SRX461554      NaN  NaN
# SRX749790      NaN  NaN
# SRX749791      NaN  NaN
# SRX749792      NaN  NaN
# SRX749793      NaN  NaN
# SRX749794      NaN  NaN
# SRX749795      NaN  NaN
# SRX749796      NaN  NaN
# SRX749797      NaN  NaN
#
# [24 rows x 22 columns]

# %%
lympho_df['Meta data'][0]
# Out:
# 'MOLECULE=genomic DNA || DISEASE=None || BIOMATERIAL_PROVIDER=FHCRC HEIMFELD || BIOMATERIAL_TYPE=Primary Cell || CELL_TYPE=CD14 Primary Cells || MARKERS=CD14+ || DONOR_ID=RO 01679 || DONOR_AGE=year 21 || DONOR_HEALTH_STATUS=NA || DONOR_SEX=Male || DONOR_ETHNICITY=Caucasian || PASSAGE_IF_EXPANDED=NA || sample_term_id=CL_0001054'

# %%
# Out:
# (688, 22)
