# %%
import os,sys
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
exp_meta_df = pd.read_pickle("./exp_metadata_df.pkl")
exp_df = pd.read_pickle("./exp_df.pkl")

# %%
exp_meta_df.to_csv('exp_meta.csv')

# %%
# Out:
#            Genome assembly   Antigen class        Antigen Cell type class  \
# ERX1270342            ce10   Input control  Input control    Unclassified
# ERX1270343            ce10  TFs and others          lir-3    Unclassified
# ERX1270344            ce10  TFs and others          lir-3    Unclassified
# ERX1485062            ce10    Unclassified   Unclassified          Embryo
# ERX1485063            ce10    Unclassified   Unclassified          Embryo
# ERX1485064            ce10    Unclassified   Unclassified          Embryo
# ERX1999196            ce10    Unclassified   Unclassified    Unclassified
# ERX1999197            ce10    Unclassified   Unclassified    Unclassified
# ERX1999198            ce10    Unclassified   Unclassified    Unclassified
# ERX1999199            ce10    Unclassified   Unclassified    Unclassified
# ERX1999200            ce10    Unclassified   Unclassified    Unclassified
# ERX1999201            ce10    Unclassified   Unclassified    Unclassified
# ...
