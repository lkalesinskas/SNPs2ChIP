# %%
% matplotlib inline

import numpy as np
import pandas as pd
import matplotlib, collections, itertools, os, re, textwrap, logging
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
from functools import reduce

from logging.config import dictConfig
from logging import getLogger

dictConfig(dict(
    version = 1,
    formatters = {'f': {'format': '%(asctime)s %(name)-12s %(levelname)-8s %(message)s'}},
    handlers = {
        'h': {'class': 'logging.StreamHandler','formatter': 'f',
              'level': logging.DEBUG}},
    root = {'handlers': ['h'], 'level': logging.DEBUG,},
))

matplotlib.rc('font',**{'size':16, 'family':'sans-serif','sans-serif':['HelveticaNeue', 'Helvetica']})

logger = getLogger('notebook')

# %%
repo_dir=os.path.realpath(
    os.path.dirname(os.path.dirname(os.getcwd()))
)

# %%
data_dir=os.path.realpath(
    os.path.join(os.path.dirname(os.getcwd()), 'private_data')
)

# %%
def read_great_res_all(filename, nrows=None, BFold=None, BPval=None, topk=None, sort_by='BPval'):
    '''Read GREAT results file (tsv) file.
    '''
    df = pd.read_table(
        filename, sep='\t', skiprows=7, nrows=nrows
    )    
    
    trues = pd.Series([True] * len(df))
    
    if (BFold is not None):
        f_BFold = df['BFold'] >= BFold
    else:
        f_BFold = trues
    
    if (BPval is not None):
        f_BPval = df['BPval'] <= BPval
    else:
        f_BPval = trues
        
    df_filtered = df[f_BFold & f_BPval]
    
    if (topk is None):
        topk = len(df_filtered)
    
    if (sort_by == 'BFold'):
        ascending=False
    else:
        ascending=True
        
    return df_filtered.sort_values(by=sort_by, ascending=ascending).head(topk)

def read_great_res(filename, nrows=None, BFold=None, BPval=None, topk=None, sort_by='BPval'):
    return read_great_res_all(filename, nrows, BFold, BPval, topk, sort_by)[['# ID', 'Desc', 'BPval', 'BFold']]

# %%
def read_great_res_wrapper(pc, ontology):
    return read_great_res(
        os.path.join(
            data_dir, 'GREAT', 'PCA{}'.format(pc), '{}.tsv'.format(ontology)
        ), 
        BFold=2.0
    )

# %% [markdown]
# # manual inspection of enrichment analysis for the first 5 components
#
# - One need to place the data files in `<repo root>/enrichment/private_data/GREAT`
#     - the data file is on google drive:
#         - https://drive.google.com/file/d/1VgjnKZ-TLPDPRB830YvYZSm8Luo7os9k/view?usp=sharing
# - Here, we can investigate the results of enrichment analysis. Please look at `<repo root>/enrichment/README.md` for method description.

# %% [markdown]
# ## Human Phenotype ontology

# %%
read_great_res_wrapper(0, 'HumanPhenotypeOntology').head()
# Out:
#          # ID                                       Desc         BPval  \
# 0  HP:0001525                   Severe failure to thrive  4.302106e-44
# 1  HP:0001833                                  Long foot  3.429376e-42
# 2  HP:0000651                                   Diplopia  1.120952e-40
# 3  HP:0011993  Impaired neutrophil bactericidal activity  4.846849e-37
# 4  HP:0001930            Nonspherocytic hemolytic anemia  9.470414e-36
#
#       BFold
# 0  29.68758
# 1  26.50561
# 2  13.99734
# 3  26.36237
# 4  24.13428

# %%
read_great_res_wrapper(1, 'HumanPhenotypeOntology').head()
# Out:
#          # ID                                       Desc         BPval  \
# 0  HP:0001525                   Severe failure to thrive  2.072890e-59
# 1  HP:0000651                                   Diplopia  7.312066e-59
# 2  HP:0001833                                  Long foot  5.131735e-57
# 3  HP:0011993  Impaired neutrophil bactericidal activity  1.433868e-56
# 4  HP:0001930            Nonspherocytic hemolytic anemia  8.824545e-55
#
#       BFold
# 0  37.10948
# 1  18.03504
# 2  33.13201
# 3  36.15411
# 4  33.09843

# %%
read_great_res_wrapper(2, 'HumanPhenotypeOntology').head()
# Out:
#          # ID                           Desc         BPval     BFold
# 0  HP:0002329                     Drowsiness  4.025085e-46  29.52977
# 1  HP:0002357                      Dysphasia  4.686590e-46  29.41936
# 2  HP:0004570     Increased vertebral height  1.383946e-45  27.02947
# 3  HP:0000651                       Diplopia  2.314844e-45  15.07406
# 4  HP:0002073  Progressive cerebellar ataxia  2.660039e-40   8.83547

# %%
read_great_res_wrapper(3, 'HumanPhenotypeOntology').head()
# Out:
#          # ID                                       Desc         BPval  \
# 0  HP:0011993  Impaired neutrophil bactericidal activity  7.387910e-43
# 1  HP:0001930            Nonspherocytic hemolytic anemia  2.054548e-41
# 2  HP:0004570                 Increased vertebral height  6.627623e-40
# 3  HP:0011990       Abnormality of neutrophil physiology  1.568841e-39
# 4  HP:0003413                   Atlantoaxial abnormality  2.911973e-37
#
#       BFold
# 0  29.37522
# 1  26.89248
# 2  24.51510
# 3  23.95739
# 4  18.69677

# %%
read_great_res_wrapper(4, 'HumanPhenotypeOntology').head()
# Out:
#          # ID                                       Desc         BPval  \
# 0  HP:0011993  Impaired neutrophil bactericidal activity  1.433868e-56
# 1  HP:0001930            Nonspherocytic hemolytic anemia  8.824545e-55
# 2  HP:0011990       Abnormality of neutrophil physiology  1.905621e-52
# 3  HP:0001525                   Severe failure to thrive  4.201000e-50
# 4  HP:0001833                                  Long foot  5.269005e-48
#
#       BFold
# 0  36.15411
# 1  33.09843
# 2  29.48602
# 3  32.65634
# 4  29.15617

# %% [markdown]
# ## GO Biological process

# %%
read_great_res_wrapper(0, 'GOBiologicalProcess').head()
# Out:
#          # ID                                               Desc  \
# 0  GO:0000185                      activation of MAPKKK activity
# 1  GO:0043249                             erythrocyte maturation
# 2  GO:0071499    cellular response to laminar fluid shear stress
# 3  GO:0007168        receptor guanylyl cyclase signaling pathway
# 4  GO:0036003  positive regulation of transcription from RNA ...
#
#           BPval     BFold
# 0  2.170690e-67  15.49817
# 1  4.447322e-60  27.24031
# 2  2.349920e-55  32.25595
# 3  6.591094e-53  18.70011
# 4  2.003572e-43  17.97852

# %%
read_great_res_wrapper(1, 'GOBiologicalProcess').head()
# Out:
#          # ID                                               Desc  \
# 0  GO:0000185                      activation of MAPKKK activity
# 1  GO:0007168        receptor guanylyl cyclase signaling pathway
# 2  GO:0043249                             erythrocyte maturation
# 3  GO:0071499    cellular response to laminar fluid shear stress
# 4  GO:2001242  regulation of intrinsic apoptotic signaling pa...
#
#           BPval      BFold
# 0  1.383495e-97  19.979570
# 1  2.872543e-81  25.356080
# 2  2.290335e-70  30.585610
# 3  2.375400e-69  38.180510
# 4  4.545917e-63   5.364207

# %%
read_great_res_wrapper(2, 'GOBiologicalProcess').head()
# Out:
#          # ID                                               Desc  \
# 0  GO:0050881                           musculoskeletal movement
# 1  GO:0046928           regulation of neurotransmitter secretion
# 2  GO:0000185                      activation of MAPKKK activity
# 3  GO:0014056  regulation of acetylcholine secretion, neurotr...
# 4  GO:0039528  cytoplasmic pattern recognition receptor signa...
#
#           BPval      BFold
# 0  4.779335e-49   7.800325
# 1  2.349345e-48   6.290903
# 2  1.268630e-45  11.950390
# 3  1.089451e-39  20.454590
# 4  1.769475e-39  23.880480

# %%
read_great_res_wrapper(3, 'GOBiologicalProcess').head()
# Out:
#          # ID                                               Desc  \
# 0  GO:0000185                      activation of MAPKKK activity
# 1  GO:0007168        receptor guanylyl cyclase signaling pathway
# 2  GO:0039528  cytoplasmic pattern recognition receptor signa...
# 3  GO:0043249                             erythrocyte maturation
# 4  GO:0010923        negative regulation of phosphatase activity
#
#           BPval      BFold
# 0  1.869970e-73  16.431790
# 1  1.017146e-64  21.552660
# 2  1.509134e-46  26.942080
# 3  1.093361e-44  21.983410
# 4  2.584073e-39   3.979831

# %%
read_great_res_wrapper(4, 'GOBiologicalProcess').head()
# Out:
#          # ID                                               Desc  \
# 0  GO:0000185                      activation of MAPKKK activity
# 1  GO:0007168        receptor guanylyl cyclase signaling pathway
# 2  GO:0039528  cytoplasmic pattern recognition receptor signa...
# 3  GO:0043249                             erythrocyte maturation
# 4  GO:0051156              glucose 6-phosphate metabolic process
#
#           BPval     BFold
# 0  3.738095e-77  16.99197
# 1  1.644075e-71  23.13742
# 2  7.480458e-57  31.22832
# 3  2.080543e-47  22.93921
# 4  1.259892e-46  22.05714

# %% [markdown]
# ## MGI Phenotype ontology (mouse phenotype)

# %%
read_great_res_wrapper(0, 'MGIPhenotype').head()
# Out:
#          # ID                                         Desc         BPval  \
# 0  MP:0004877        abnormal systemic vascular resistance  1.175745e-64
# 1  MP:0003394                     increased cardiac output  2.993274e-61
# 2  MP:0008539  decreased susceptibility to induced colitis  1.875374e-55
# 3  MP:0011951              increased cardiac stroke volume  5.387074e-54
# 4  MP:0005348               increased T cell proliferation  8.861567e-54
#
#        BFold
# 0  38.138700
# 1  34.511170
# 2  10.227910
# 3  26.068020
# 4   3.680493

# %%
read_great_res_wrapper(1, 'MGIPhenotype').head()
# Out:
#          # ID                                         Desc         BPval  \
# 0  MP:0001800             abnormal humoral immune response  9.552577e-87
# 1  MP:0002490                abnormal immunoglobulin level  2.302866e-83
# 2  MP:0008210               increased mature B cell number  2.886921e-83
# 3  MP:0011951              increased cardiac stroke volume  2.586089e-79
# 4  MP:0008539  decreased susceptibility to induced colitis  5.007180e-79
#
#        BFold
# 0   2.416677
# 1   2.459878
# 2   4.035475
# 3  34.590260
# 4  12.844360

# %%
read_great_res_wrapper(2, 'MGIPhenotype').head()
# Out:
#          # ID                                   Desc         BPval      BFold
# 0  MP:0009310         large intestine adenocarcinoma  2.993071e-42  14.544560
# 1  MP:0008210         increased mature B cell number  7.798192e-40   2.923224
# 2  MP:0003394               increased cardiac output  6.477863e-35  22.790390
# 3  MP:0006038  increased mitochondrial proliferation  8.018869e-35  10.559900
# 4  MP:0008840          abnormal spike wave discharge  3.616096e-33   5.614086

# %%
read_great_res_wrapper(3, 'MGIPhenotype').head()
# Out:
#          # ID                                   Desc         BPval      BFold
# 0  MP:0008210         increased mature B cell number  1.013412e-55   3.365273
# 1  MP:0004877  abnormal systemic vascular resistance  1.086916e-50  31.782250
# 2  MP:0004796  increased anti-histone antibody level  2.566619e-50  10.620570
# 3  MP:0003394               increased cardiac output  3.747434e-49  29.301930
# 4  MP:0009310         large intestine adenocarcinoma  1.308234e-44  15.093410

# %%
read_great_res_wrapper(4, 'MGIPhenotype').head()
# Out:
#          # ID                                         Desc         BPval  \
# 0  MP:0004796        increased anti-histone antibody level  3.875817e-63
# 1  MP:0008539  decreased susceptibility to induced colitis  1.033266e-62
# 2  MP:0008210               increased mature B cell number  1.089594e-60
# 3  MP:0005348               increased T cell proliferation  1.070219e-59
# 4  MP:0003394                     increased cardiac output  1.198807e-56
#
#        BFold
# 0  12.297510
# 1  11.060420
# 2   3.493609
# 3   3.861798
# 4  32.557700
