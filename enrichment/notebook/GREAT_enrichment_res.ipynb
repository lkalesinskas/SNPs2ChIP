# %% [markdown]
# # manual inspection of enrichment analysis for the first 5 components
#
# - One need to place the data files in `<repo root>/enrichment/private_data/GREAT`
#     - the data file is on google drive:
#         - https://drive.google.com/file/d/1j2F0w_r9Y-cRdAh0UrDy-QZl4qWndK8W/view?usp=sharing
# - Here, we can investigate the results of enrichment analysis. Please look at `<repo root>/enrichment/README.md` for method description.

# %%
% matplotlib inline

import numpy as np
import pandas as pd
import matplotlib, collections, itertools, os, re, textwrap, logging, sys
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
from functools import reduce

from logging.config import dictConfig
from logging import getLogger

dictConfig(dict(
    version = 1,
    formatters = {'f': {'format': '%(asctime)s %(name)-12s %(levelname)-8s %(message)s'}},
    handlers = {
        'h': {'class': 'logging.StreamHandler','formatter': 'f',
              'level': logging.DEBUG}},
    root = {'handlers': ['h'], 'level': logging.DEBUG,},
))

matplotlib.rc('font',**{'size':16, 'family':'sans-serif','sans-serif':['HelveticaNeue', 'Helvetica']})

logger = getLogger('notebook')

# %%
repo_dir=os.path.realpath(
    os.path.dirname(os.path.dirname(os.getcwd()))
)

# %%
data_dir=os.path.realpath(
    os.path.join(os.path.dirname(os.getcwd()), 'private_data')
)

# %%
sys.path.append(os.path.join(repo_dir, 'enrichement', 'src'))
from great import read_great_res_wrapper

# %% [markdown]
# ## Gene Ontology (GO) Biological process

# %%
read_great_res_wrapper(data_dir, 0, 'GOBiologicalProcess').head()
# Out:
#           # ID                                            Desc         BPval  \
# 19  GO:0080111                               DNA demethylation  3.780717e-08
# 20  GO:0046133     pyrimidine ribonucleoside catabolic process  4.080519e-08
# 26  GO:0006703                   estrogen biosynthetic process  9.438592e-08
# 29  GO:0045916    negative regulation of complement activation  1.792544e-07
# 35  GO:0033081  regulation of T cell differentiation in thymus  5.234933e-07
#
#        BFold
# 19  3.904828
# 20  6.249585
# 26  3.843655
# 29  4.370029
# 35  2.308571

# %%
read_great_res_wrapper(data_dir, 1, 'GOBiologicalProcess').head()
# Out:
#           # ID                                             Desc         BPval  \
# 5   GO:0043901    negative regulation of multi-organism process  1.318940e-07
# 8   GO:0050830      defense response to Gram-positive bacterium  5.854487e-07
# 9   GO:0043374  CD8-positive, alpha-beta T cell differentiation  7.974458e-07
# 14  GO:0006572                       tyrosine catabolic process  1.401399e-06
# 17  GO:0002286    T cell activation involved in immune response  3.720987e-06
#
#        BFold
# 5   2.168513
# 8   2.436218
# 9   2.954704
# 14  7.532955
# 17  2.339229

# %%
read_great_res_wrapper(data_dir, 2, 'GOBiologicalProcess').head()
# Out:
#           # ID                                               Desc  \
# 30  GO:0060333        interferon-gamma-mediated signaling pathway
# 39  GO:0045047                            protein targeting to ER
# 44  GO:0071346              cellular response to interferon-gamma
# 45  GO:0038096  Fc-gamma receptor signaling pathway involved i...
# 47  GO:0002431  Fc receptor mediated stimulatory signaling pat...
#
#            BPval     BFold
# 30  9.010372e-11  2.559231
# 39  3.183959e-10  2.280882
# 44  5.468346e-10  2.159660
# 45  5.472179e-10  2.147846
# 47  5.672283e-10  2.146109

# %%
read_great_res_wrapper(data_dir, 3, 'GOBiologicalProcess').head()
# Out:
#            # ID                                               Desc     BPval  \
# 92   GO:0075733                   intracellular transport of virus  0.000015
# 99   GO:0071624      positive regulation of granulocyte chemotaxis  0.000017
# 106  GO:0090023       positive regulation of neutrophil chemotaxis  0.000021
# 110  GO:0070127  tRNA aminoacylation for mitochondrial protein ...  0.000021
# 139  GO:0018401  peptidyl-proline hydroxylation to 4-hydroxy-L-...  0.000038
#
#         BFold
# 92   2.074477
# 99   2.064859
# 106  2.068764
# 110  4.215114
# 139  2.430515

# %%
read_great_res_wrapper(data_dir, 4, 'GOBiologicalProcess').head()
# Out:
#           # ID                                               Desc     BPval  \
# 39  GO:0042219     cellular modified amino acid catabolic process  0.000010
# 66  GO:0042447                          hormone catabolic process  0.000076
# 76  GO:0006590                         thyroid hormone generation  0.000106
# 79  GO:0048714  positive regulation of oligodendrocyte differe...  0.000115
# 94  GO:0001542                    ovulation from ovarian follicle  0.000138
#
#        BFold
# 39  2.204023
# 66  2.530917
# 76  2.011829
# 79  2.025767
# 94  2.243419

# %% [markdown]
# ## Human Phenotype ontology
#
# Human Phenotype Ontology is an ontology with human phenotypes (often derived from diseases) with gene <--> disease mapping

# %%
read_great_res_wrapper(data_dir, 0, 'HumanPhenotypeOntology').head()
# Out:
#           # ID                                          Desc         BPval  \
# 3   HP:0012140  Abnormality of cells of the lymphoid lineage  3.637427e-07
# 5   HP:0001888                                   Lymphopenia  5.567840e-07
# 11  HP:0001878                              Hemolytic anemia  1.152956e-06
# 13  HP:0002917                                Hypomagnesemia  3.079205e-06
# 20  HP:0004921          Abnormality of magnesium homeostasis  5.371737e-05
#
#        BFold
# 3   2.315639
# 5   2.382784
# 11  2.008804
# 13  3.452539
# 20  2.814905

# %%
read_great_res_wrapper(data_dir, 1, 'HumanPhenotypeOntology').head()
# Out:
#          # ID                                               Desc     BPval  \
# 0  HP:0004395                                       Malnutrition  0.000005
# 1  HP:0001718                                    Mitral stenosis  0.000063
# 2  HP:0001413                             Micronodular cirrhosis  0.000120
# 5  HP:0004333                             Bone-marrow foam cells  0.000345
# 6  HP:0003548  Subsarcolemmal accumulations of abnormally sha...  0.000527
#
#       BFold
# 0  5.321346
# 1  3.783898
# 2  2.821075
# 5  6.657703
# 6  6.137533

# %%
read_great_res_wrapper(data_dir, 2, 'HumanPhenotypeOntology').head()
# Out:
#           # ID                                     Desc         BPval  \
# 8   HP:0012103         Abnormality of the mitochondrion  1.981297e-08
# 11  HP:0003287  Abnormality of mitochondrial metabolism  5.547277e-08
# 16  HP:0010972          Anemia of inadequate production  1.467984e-07
# 20  HP:0200042                               Skin ulcer  2.149489e-07
# 22  HP:0001581                Recurrent skin infections  3.267830e-07
#
#        BFold
# 8   2.430178
# 11  2.397021
# 16  2.084019
# 20  2.021010
# 22  2.644626

# %%
read_great_res_wrapper(data_dir, 3, 'HumanPhenotypeOntology').head()
# Out:
#          # ID                                 Desc         BPval     BFold
# 0  HP:0002697                    Parietal foramina  5.211070e-08  2.381946
# 2  HP:0004425                        Flat forehead  9.815947e-07  2.801818
# 3  HP:0002365          Hypoplasia of the brainstem  1.226172e-06  2.080713
# 4  HP:0004442            Sagittal craniosynostosis  1.499563e-06  2.798936
# 5  HP:0010054  Abnormality of the first metatarsal  1.545575e-06  2.636819

# %%
read_great_res_wrapper(data_dir, 4, 'HumanPhenotypeOntology').head()
# Out:
#            # ID                                               Desc     BPval  \
# 0    HP:0001029                                       Poikiloderma  0.000207
# 1    HP:0003079  Defective DNA repair after ultraviolet radiati...  0.000212
# 54   HP:0010758                      Abnormality of the premaxilla  0.008194
# 83   HP:0004326                                           Cachexia  0.013697
# 108  HP:0003216                     Generalized amyloid deposition  0.019079
#
#         BFold
# 0    2.412633
# 1    2.784793
# 54   2.271427
# 83   2.114202
# 108  2.903179

# %% [markdown]
# ## MGI Phenotype ontology (mouse phenotype)
#
# Mouse has comprehensive catalog of gene-phenotype mapping. (We can't perform experiments on human).

# %%
read_great_res_wrapper(data_dir, 0, 'MGIPhenotype').head()
# Out:
#           # ID                                               Desc     BPval  \
# 26  MP:0001856                                        myocarditis  0.000003
# 34  MP:0001870                        salivary gland inflammation  0.000007
# 36  MP:0004041  increased susceptibility to kidney reperfusion...  0.000008
# 44  MP:0002389         abnormal Peyer's patch follicle morphology  0.000018
# 60  MP:0002392      abnormal Peyer's patch T cell area morphology  0.000067
#
#        BFold
# 26  2.899189
# 34  2.334535
# 36  4.074445
# 44  2.146357
# 60  3.541650

# %%
read_great_res_wrapper(data_dir, 1, 'MGIPhenotype').head()
# Out:
#           # ID                                               Desc  \
# 5   MP:0008552   abnormal circulating tumor necrosis factor level
# 25  MP:0006309             decreased retinal ganglion cell number
# 38  MP:0008553  increased circulating tumor necrosis factor level
# 40  MP:0008392              decreased primordial germ cell number
# 54  MP:0008554  decreased circulating tumor necrosis factor level
#
#            BPval     BFold
# 5   5.025154e-11  2.137410
# 25  1.466071e-07  2.196054
# 38  9.253086e-07  2.065763
# 40  1.079230e-06  2.054944
# 54  2.946674e-06  2.397094

# %%
read_great_res_wrapper(data_dir, 2, 'MGIPhenotype').head()
# Out:
#           # ID                                      Desc         BPval  \
# 17  MP:0005153             abnormal B cell proliferation  3.181409e-20
# 21  MP:0008217                abnormal B cell activation  3.436036e-18
# 37  MP:0005093            decreased B cell proliferation  7.882232e-15
# 41  MP:0008180  abnormal marginal zone B cell morphology  2.404651e-14
# 45  MP:0008495                      decreased IgG1 level  9.733961e-14
#
#        BFold
# 17  2.120136
# 21  2.012082
# 37  2.142833
# 41  2.229240
# 45  2.015448

# %%
read_great_res_wrapper(data_dir, 3, 'MGIPhenotype').head()
# Out:
#           # ID                                        Desc         BPval  \
# 14  MP:0001771        abnormal circulating magnesium level  2.258230e-07
# 18  MP:0003954     abnormal Reichert's membrane morphology  3.972634e-07
# 48  MP:0010092       increased circulating magnesium level  6.732819e-06
# 52  MP:0009545  abnormal dermis papillary layer morphology  9.978618e-06
# 55  MP:0001669                 abnormal glucose absorption  1.529968e-05
#
#        BFold
# 14  2.333532
# 18  2.052724
# 48  2.691314
# 52  2.329184
# 55  2.681345

# %%
read_great_res_wrapper(data_dir, 4, 'MGIPhenotype').head()
# Out:
#           # ID                                            Desc         BPval  \
# 0   MP:0004494             abnormal synaptic glutamate release  5.094085e-08
# 2   MP:0004495            decreased synaptic glutamate release  1.044523e-07
# 15  MP:0003276                              esophageal atresia  2.694408e-05
# 53  MP:0003282                                   gastric ulcer  2.993688e-04
# 57  MP:0010779  abnormal stomach muscularis externa morphology  3.253070e-04
#
#        BFold
# 0   2.254817
# 2   2.613689
# 15  2.157871
# 53  2.347075
# 57  2.088876

# %% [markdown]
# ## MGI Phenotype ontology (knockout only) (mouse phenotype, derived from KO analysis)
#
# KO subset of MGI Phenotype ontology is sometimes useful (to narrow down to causal relationship)

# %% [markdown]
# ## GO Molecular function

# %%
read_great_res_wrapper(data_dir, 0, 'MGIPhenoSingleKO').head()
# Out:
#           # ID                                               Desc     BPval  \
# 24  MP:0001856                                        myocarditis  0.000003
# 29  MP:0004041  increased susceptibility to kidney reperfusion...  0.000008
# 35  MP:0008126                    increased dendritic cell number  0.000017
# 59  MP:0008862                                   asymmetric snout  0.000070
# 63  MP:0003452                  abnormal parotid gland morphology  0.000087
#
#        BFold
# 24  3.121352
# 29  4.074445
# 35  2.882200
# 59  2.759692
# 63  3.455479

# %%
read_great_res_wrapper(data_dir, 1, 'MGIPhenoSingleKO').head()
# Out:
#           # ID                                               Desc  \
# 16  MP:0008552   abnormal circulating tumor necrosis factor level
# 47  MP:0009788  increased susceptibility to bacterial infectio...
# 55  MP:0008554  decreased circulating tumor necrosis factor level
# 61  MP:0009321            increased histiocytic sarcoma incidence
# 75  MP:0006309             decreased retinal ganglion cell number
#
#            BPval     BFold
# 16  6.418123e-08  2.067143
# 47  3.363712e-06  2.019205
# 55  7.000738e-06  2.367790
# 61  1.319572e-05  2.534863
# 75  3.783763e-05  2.174031

# %%
read_great_res_wrapper(data_dir, 2, 'MGIPhenoSingleKO').head()
# Out:
#           # ID                                         Desc         BPval  \
# 29  MP:0005153                abnormal B cell proliferation  2.973987e-14
# 40  MP:0005461           abnormal dendritic cell morphology  1.445606e-12
# 42  MP:0001806                          decreased IgM level  3.291375e-12
# 53  MP:0005093               decreased B cell proliferation  1.718479e-10
# 70  MP:0002418  increased susceptibility to viral infection  8.788483e-09
#
#        BFold
# 29  2.068460
# 40  2.379902
# 42  2.209544
# 53  2.145825
# 70  2.034574

# %%
read_great_res_wrapper(data_dir, 3, 'MGIPhenoSingleKO').head()
# Out:
#           # ID                                     Desc         BPval  \
# 5   MP:0012129          failure of blastocyst formation  7.850076e-10
# 6   MP:0012128            abnormal blastocyst formation  9.198091e-10
# 7   MP:0002663               failure to form blastocele  1.228421e-09
# 9   MP:0004963          abnormal blastocoele morphology  2.117273e-09
# 19  MP:0003954  abnormal Reichert's membrane morphology  3.972634e-07
#
#        BFold
# 5   2.053477
# 6   2.046508
# 7   2.052544
# 9   2.009879
# 19  2.052724

# %%
read_great_res_wrapper(data_dir, 4, 'MGIPhenoSingleKO').head()
# Out:
#           # ID                                  Desc         BPval     BFold
# 2   MP:0004494   abnormal synaptic glutamate release  8.093472e-07  2.224995
# 3   MP:0001661                    extended life span  1.476395e-06  2.641572
# 5   MP:0004495  decreased synaptic glutamate release  1.703522e-06  2.536114
# 7   MP:0003990    decreased neurotransmitter release  5.253076e-06  2.196289
# 18  MP:0005109             abnormal talus morphology  5.978991e-05  2.180961

# %% [markdown]
# ## GO Cellular component

# %%
read_great_res_wrapper(data_dir, 0, 'GOCellularComponent').head()
# Out:
#           # ID                                               Desc  \
# 4   GO:0042611                                MHC protein complex
# 17  GO:0071556  integral to lumenal side of endoplasmic reticu...
# 20  GO:0042612                        MHC class I protein complex
# 21  GO:0042613                       MHC class II protein complex
# 26  GO:0005761                             mitochondrial ribosome
#
#            BPval     BFold
# 4   1.528314e-09  4.026781
# 17  5.172804e-06  3.113123
# 20  9.299293e-06  3.610470
# 21  2.079056e-05  3.733819
# 26  4.195153e-05  2.000761

# %%
read_great_res_wrapper(data_dir, 1, 'GOCellularComponent').head()
# Out:
#           # ID                             Desc     BPval     BFold
# 1   GO:0030125            clathrin vesicle coat  0.000067  2.552380
# 2   GO:0030934               anchoring collagen  0.000224  2.456392
# 5   GO:0005861                 troponin complex  0.000632  7.499313
# 10  GO:0002199  zona pellucida receptor complex  0.001140  4.497283
# 12  GO:0031932                    TORC2 complex  0.001389  3.227893

# %%
read_great_res_wrapper(data_dir, 2, 'GOCellularComponent').head()
# Out:
#           # ID                                               Desc  \
# 9   GO:0005758                  mitochondrial intermembrane space
# 15  GO:0000307  cyclin-dependent protein kinase holoenzyme com...
# 20  GO:0000788                                 nuclear nucleosome
# 27  GO:0044798               nuclear transcription factor complex
# 31  GO:0031095            platelet dense tubular network membrane
#
#            BPval     BFold
# 9   4.658954e-08  2.924884
# 15  1.661690e-06  2.979384
# 20  3.649093e-06  6.005715
# 27  1.326775e-05  2.009501
# 31  2.117509e-05  3.726373

# %%
read_great_res_wrapper(data_dir, 3, 'GOCellularComponent').head()
# Out:
#           # ID                                     Desc     BPval     BFold
# 8   GO:0005606                        laminin-1 complex  0.000008  2.211307
# 9   GO:0043256                          laminin complex  0.000032  2.046880
# 22  GO:0019031                           viral envelope  0.000486  2.907735
# 46  GO:0031080                  nuclear pore outer ring  0.002169  2.309853
# 54  GO:0005666  DNA-directed RNA polymerase III complex  0.003262  2.282204

# %%
read_great_res_wrapper(data_dir, 4, 'GOCellularComponent').head()
# Out:
#           # ID                                         Desc     BPval  \
# 2   GO:0005750  mitochondrial respiratory chain complex III  0.000062
# 9   GO:0032591                     dendritic spine membrane  0.001123
# 16  GO:0031094               platelet dense tubular network  0.005397
# 24  GO:0031095      platelet dense tubular network membrane  0.011675
# 52  GO:0005655             nucleolar ribonuclease P complex  0.056398
#
#        BFold
# 2   3.094238
# 9   2.926314
# 16  2.095931
# 24  2.023305
# 52  2.225361
