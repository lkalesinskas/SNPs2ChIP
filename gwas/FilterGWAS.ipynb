# %%
import pandas as pd
df = pd.read_csv('gwas_catalog.tsv', sep="\t")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (11,12,23,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
list(df)
# Out:
# ['DATE ADDED TO CATALOG',
#  'PUBMEDID',
#  'FIRST AUTHOR',
#  'DATE',
#  'JOURNAL',
#  'LINK',
#  'STUDY',
#  'DISEASE/TRAIT',
#  'INITIAL SAMPLE SIZE',
#  'REPLICATION SAMPLE SIZE',
#  'REGION',
#  'CHR_ID',
#  'CHR_POS',
#  'REPORTED GENE(S)',
#  'MAPPED_GENE',
#  'UPSTREAM_GENE_ID',
#  'DOWNSTREAM_GENE_ID',
#  'SNP_GENE_IDS',
#  'UPSTREAM_GENE_DISTANCE',
#  'DOWNSTREAM_GENE_DISTANCE',
#  'STRONGEST SNP-RISK ALLELE',
#  'SNPS',
#  'MERGED',
#  'SNP_ID_CURRENT',
#  'CONTEXT',
#  'INTERGENIC',
#  'RISK ALLELE FREQUENCY',
#  'P-VALUE',
#  'PVALUE_MLOG',
#  'P-VALUE (TEXT)',
#  'OR or BETA',
#  '95% CI (TEXT)',
#  'PLATFORM [SNPS PASSING QC]',
#  'CNV']

# %%
#select which columns are wanted - disease, chr #, chromosome position, type of SNP, intergenic/not
truncatedTable = df.filter(items=['DISEASE/TRAIT', 'CHR_ID', 'CHR_POS', 'CONTEXT', 'INTERGENIC'])
print(truncatedTable)
# Out:
#                                            DISEASE/TRAIT CHR_ID    CHR_POS  \
# 0                                     Systemic sclerosis      6   32701379
# 1                                     Systemic sclerosis      6   32251212
# 2                                     Systemic sclerosis      6   32441753
# 3                                     Systemic sclerosis      6   33075103
# 4                                     Systemic sclerosis      6   32623148
# 5      Drug-induced Stevens-Johnson syndrome or toxic...      6   31039078
# 6      Drug-induced Stevens-Johnson syndrome or toxic...      6   31125810
# 7      Drug-induced Stevens-Johnson syndrome or toxic...      6   31168676
# 8      Drug-induced Stevens-Johnson syndrome or toxic...      6   31440051
# 9                                        Prostate cancer      2   85567174
# 10                                       Prostate cancer      2  237478585
# ...

# %%
#types of variants -- way too many.
truncatedTable.CONTEXT.unique()
# Out:
# array(['intergenic_variant', 'intron_variant',
#        'regulatory_region_variant', '5_prime_UTR_variant',
#        'missense_variant', '3_prime_UTR_variant',
#        'non_coding_transcript_exon_variant', nan, 'synonymous_variant',
#        'stop_gained', 'splice_acceptor_variant',
#        'TF_binding_site_variant', 'splice_region_variant',
#        'synonymous_variant; non_coding_transcript_exon_variant',
#        'regulatory_region_variant; missense_variant; intron_variant; intergenic_variant; intron_variant; intron_variant; intergenic_variant; intron_variant; intron_variant; 3_prime_UTR_variant; intron_variant; intron_variant; intergenic_variant; intron_variant; intron_variant; intron_variant',
#        'regulatory_region_variant; intergenic_variant',
#        'intergenic_variant; intergenic_variant; intron_variant',
#        'frameshift_variant',
#        'intron_variant; intron_variant; intron_variant',
# ...

# %%
#Filtering out the GWAS variants that are labeled as "intergenic" -> May need to do more specific filtration later?
filteredOutIntergenic = truncatedTable.loc[truncatedTable['INTERGENIC'] == 0.0]
print(filteredOutIntergenictergenic)
# Out:
#                                            DISEASE/TRAIT CHR_ID    CHR_POS  \
# 2                                     Systemic sclerosis      6   32441753
# 3                                     Systemic sclerosis      6   33075103
# 6      Drug-induced Stevens-Johnson syndrome or toxic...      6   31125810
# 7      Drug-induced Stevens-Johnson syndrome or toxic...      6   31168676
# 11                                       Prostate cancer      3  141383991
# 13                                       Prostate cancer      5    1279913
# 14                                       Prostate cancer      5   44365443
# 15                                       Prostate cancer      6   31150734
# 18                                       Type 2 diabetes     11    2822986
# 20                                       Hepcidin levels      6   26092913
# 21                                       Hepcidin levels      6   26092913
# ...

# %%
#output filteredOutIntergenic table to file
filteredOutIntergenic.to_csv("outputSNPs.csv", sep=',')
