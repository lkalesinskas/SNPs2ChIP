# %% [markdown]
# ## VDR chr2_33701 example -- Which component is important?
#
# - The specific context of this variant and disease is described in this google doc:
#   - https://docs.google.com/document/d/16GuSasXWX-5qwvKAX5-4VxtrbmsIu9UgrP311_viqQc/edit?usp=sharing
# - This notebook would show,
#   1. Given the SNP, identify which genomic bin contains the SNP
#   1. Use genomic bin squared cosine score to find the top 3 important components for the genomic bin
#   1. Investigate the top component for the genomic bins
#     - Use assay contribution scores to see what assays are important for the component
#     - Use genomic bin contribution scores to see what other gnomic bins are important for the component
#     - Explorer the results of enrichment analysis

# %%
% matplotlib inline

import numpy as np
import pandas as pd
import matplotlib, collections, itertools, os, re, textwrap, logging, sys
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
from functools import reduce

from logging.config import dictConfig
from logging import getLogger

dictConfig(dict(
    version = 1,
    formatters = {'f': {'format': '%(asctime)s %(name)-12s %(levelname)-8s %(message)s'}},
    handlers = {
        'h': {'class': 'logging.StreamHandler','formatter': 'f',
              'level': logging.DEBUG}},
    root = {'handlers': ['h'], 'level': logging.DEBUG,},
))

matplotlib.rc('font',**{'size':16, 'family':'sans-serif','sans-serif':['HelveticaNeue', 'Helvetica']})

logger = getLogger('notebook')

# %%
repo_dir=os.path.realpath(
    os.path.dirname(os.path.dirname(os.getcwd()))
)

# %%
data_dir=os.path.realpath(
    os.path.join(os.path.dirname(os.getcwd()), 'private_data')
)

# %%
enrichment_data_dir=os.path.join(repo_dir, 'enrichment', 'private_data')

# %%
sys.path.append(os.path.join(repo_dir, 'enrichment', 'src'))
from great import read_great_res_wrapper

# %%
metadata_dir=os.path.join(
    repo_dir, 'metadata'
)
metadata = pd.read_table(
    os.path.join(metadata_dir, 'sample_antibody_map_v2_with_metadata.tsv'),
    sep='\t',
)

# %% [markdown]
# ### Step 1: SNP to genomic bin

# %%
genomic_bin_df=pd.read_csv(
    os.path.join(repo_dir, 'enrichment', 'private_data', 'loci_def.bed'),
    names=['chr', 'chromStart', 'chromEnd', 'name'],
    sep='\t'
)

# %%
genomic_bin_df[genomic_bin_df['name'] == 'chr2_33701']
# Out:
#         chr  chromStart  chromEnd        name
# 40973  chr2    33701000  33702000  chr2_33701

# %% [markdown]
# This means the index of the genomic bin of our interest is 40973

# %%
genomic_bin_idx=40973

# %% [markdown]
# ### Step 2: Which component is important for a given genomic bin -- genomic bin squared cosine score
# - Let's write our decomposition as X = UDV' where X is input feature matrix, D is diagonal singular value matrix, U is left singular vector matrix (on assay space), V is right singular vector matrix (on genomic bin space), and `'` denotes the transposition of the matrix.
# - Genomic bin squared cosine score is defined as L2-normalized version of the matrix product (VD) so that any given slice for a given genomic bin has Euclidian norm of 1.
# - The interpretation of the score is it represents the relative importance of the component given a genomic bin.
# - More formal definition:
#   - https://docs.google.com/document/d/1YRuaIvHvjb_6SJwlml1dQDegiGlGbdfz_zN-5bneroE/edit?usp=sharing

# %% [markdown]
# #### read the decomposed matrices

# %%
def read_decomposed_matrix(filename, compression=None):
    if((compression is None) and (len(filename) > 3) and (filename[-3:] == '.gz')):
        compression='gzip'
    df = pd.read_csv(
        os.path.join(data_dir, filename),
        compression=compression
    )
    mat = df.iloc[:, 1:].as_matrix()
    idx = df.iloc[:, 0].as_matrix()
    return mat, idx

# %%
d_mat_temp, d_idx = read_decomposed_matrix(os.path.join(data_dir, 'diagonalScore.csv.gz'))
d_vec = d_mat_temp[:, 0]

# %%
u_mat, u_idx = read_decomposed_matrix(os.path.join(data_dir, 'uScore.csv.gz'))

# %%
v_mat, v_idx = read_decomposed_matrix(os.path.join(data_dir, 'vScore.csv.gz'))

# %%
d_vec.shape, u_mat.shape, v_mat.shape, d_idx.shape, u_idx.shape, v_idx.shape
# Out:
# ((652,), (652, 652), (379541, 652), (652,), (652,), (379541,))

# %% [markdown]
# #### compute matrix products, UD and VD

# %%
u_dot_d = np.dot(u_mat, np.diag(d_vec))

# %%
v_dot_d = np.dot(v_mat, np.diag(d_vec))

# %%
u_dot_d.shape, v_dot_d.shape
# Out:
# ((652, 652), (379541, 652))

# %% [markdown]
# #### compute normalized matrices
# - v_dot_d_find_pcs: genomic bin --> which PC? genomic bin squared contribution score.
# - u_dot_d_fine_pcs: assay       --> which PC? assay squared contribution score.
# - v_dot_d_find_loci: PC --> which genomic bins? genomic bin contribution score.
# - u_dot_d_find_assay: PC --> which assay? assay contribution score

# %%
v_dot_d_find_pcs = (v_dot_d ** 2 ) / (np.sum(v_dot_d ** 2, axis = 1)[:,np.newaxis])

# %%
u_dot_d_find_pcs = (u_dot_d ** 2 ) / (np.sum(u_dot_d ** 2, axis = 1)[:,np.newaxis])

# %%
v_dot_d_find_loci = (v_dot_d ** 2 ) / (np.sum(v_dot_d ** 2, axis = 0)[np.newaxis, :])

# %%
u_dot_d_find_assay = (u_dot_d ** 2 ) / (np.sum(u_dot_d ** 2, axis = 0)[np.newaxis, :])

# %% [markdown]
# #### let's identify the top 3 important components for the genomic bin

# %%
np.argsort(-v_dot_d_find_pcs[genomic_bin_idx, :])[:5]
# Out:
# array([ 0,  5,  2,  8, 39])

# %%
v_dot_d_find_pcs[genomic_bin_idx, np.argsort(-v_dot_d_find_pcs[genomic_bin_idx, :])[:5]]
# Out:
# array([0.17388874, 0.14292424, 0.07116638, 0.05649573, 0.02586899])

# %% [markdown]
# This means PC0 (0-based index) is the most important component for this bin with 17.4% of squared cosine score, PC5 is the second important one with 14.2%, etc ...

# %% [markdown]
# ### Step 3: investigation of the components

# %% [markdown]
# #### PC0 (the top component)
#
# We will investigate
#
# 1. What assays are driving this component?
# 1. What genomic loci are driving this component?
# 1.  What are the top hits in the enrichment analysis?

# %%
component_idx=0

# %% [markdown]
# #### what assays are driving this component?

# %%
np.argsort(-u_dot_d_find_assay[:, component_idx])[:5]
# Out:
# array([193, 192,  93, 194,  28])

# %%
u_dot_d_find_assay[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], component_idx]
# Out:
# array([0.49684131, 0.31340371, 0.05643114, 0.01414899, 0.00910366])

# %%
metadata.iloc[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], :]
# Out:
#     sample_number antibody Genome assembly Antigen class       Antigen  \
# 193     SRX106085      NaN            hg19       Histone      H3K27me3
# 192     SRX106084      NaN            hg19       Histone      H3K27me3
# 93      ERX329704      NaN            hg19  Unclassified  Unclassified
# 194     SRX106087      NaN            hg19       Histone      H3K27me3
# 28      ERX329639      NaN            hg19  Unclassified  Unclassified
#
#     Cell type class                 Cell type  \
# 193           Blood  Lymphoblastoid cell line
# 192           Blood  Lymphoblastoid cell line
# 93            Blood  Lymphoblastoid cell line
# 194           Blood  Lymphoblastoid cell line
# 28            Blood  Lymphoblastoid cell line
#
#                                  Cell type description  \
# 193  Tissue=blood|Lineage=mesoderm|Description=pare...
# 192  Tissue=blood|Lineage=mesoderm|Description=pare...
# 93   Tissue=blood|Lineage=mesoderm|Description=pare...
# 194  Tissue=blood|Lineage=mesoderm|Description=pare...
# 28   Tissue=blood|Lineage=mesoderm|Description=pare...
#
#               Processing logs  \
# 193  50863687,47.0,38.0,44910
# 192  45470156,35.1,60.9,34413
# 93   53432856,37.9,67.7,21958
# 194  46755455,53.5,22.7,10811
# 28   48478749,83.7,14.8,38430
#
#                                                  Title   ...   age  treatment  \
# 193    GSM835575: WBS H3K27me3; Homo sapiens; ChIP-Seq   ...   NaN        NaN
# 192    GSM835574: SMS H3K27me3; Homo sapiens; ChIP-Seq   ...   NaN        NaN
# 93   Illumina HiSeq 2000 sequencing; Coordinated ef...   ...   NaN        NaN
# 194   GSM835577: Ctrl H3K27me3; Homo sapiens; ChIP-Seq   ...   NaN        NaN
# 28   Illumina Genome Analyzer IIx sequencing; Coord...   ...   NaN        NaN
#
#     genotype lab  age.1 health state  cell_type  tissue_type  provider     sex
# 193      NaN NaN    NaN          NaN        NaN          NaN       NaN     NaN
# 192      NaN NaN    NaN          NaN        NaN          NaN       NaN     NaN
# 93       NaN NaN    NaN          NaN    NA11830          NaN       NaN  female
# 194      NaN NaN    NaN          NaN        NaN          NaN       NaN     NaN
# 28       NaN NaN    NaN          NaN    NA12892          NaN       NaN  female
#
# [5 rows x 24 columns]

# %% [markdown]
# #### what genomic bins are driving this component?

# %%
np.argsort(-v_dot_d_find_loci[:, component_idx])[:5]
# Out:
# array([310943, 291154,  64617, 213360, 217066])

# %%
v_dot_d_find_loci[np.argsort(-v_dot_d_find_loci[:, component_idx])[:5], component_idx]
# Out:
# array([3.14733015e-05, 3.14360980e-05, 3.14233214e-05, 3.14025649e-05,
#        3.14000381e-05])

# %% [markdown]
# These genomic bins are important for PC16. Note the genomic bin contribution scores are very small compared to assay contribution score. This is expected becasue of the large number of genomic bins in the whole-genome analysis.

# %% [markdown]
# #### where is our loci of interest in this ranking?

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[
    genomic_bin_idx, component_idx])
# Out:
# 52379

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[
    genomic_bin_idx, component_idx]) / v_dot_d_find_loci.shape[0]
# Out:
# 0.1380061706113437

# %% [markdown]
# It's roughly on the top 14 percentile.

# %% [markdown]
# #### results of the enrichment analysis

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'HumanPhenotypeOntology').head(10)
# Out:
#           # ID                                          Desc         BPval  \
# 3   HP:0012140  Abnormality of cells of the lymphoid lineage  3.637427e-07
# 5   HP:0001888                                   Lymphopenia  5.567840e-07
# 11  HP:0001878                              Hemolytic anemia  1.152956e-06
# 13  HP:0002917                                Hypomagnesemia  3.079205e-06
# 20  HP:0004921          Abnormality of magnesium homeostasis  5.371737e-05
# 22  HP:0000121                              Nephrocalcinosis  8.832524e-05
# 24  HP:0200114                           Metabolic alkalosis  1.073928e-04
# 25  HP:0002643                 Neonatal respiratory distress  1.307868e-04
# 27  HP:0000360                                      Tinnitus  1.513635e-04
# 28  HP:0001281                                        Tetany  1.785555e-04
#
#        BFold
# 3   2.315639
# 5   2.382784
# 11  2.008804
# 13  3.452539
# 20  2.814905
# 22  2.448755
# 24  4.508408
# 25  3.743395
# 27  2.679365
# 28  2.937869

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOBiologicalProcess').head(10)
# Out:
#           # ID                                            Desc         BPval  \
# 19  GO:0080111                               DNA demethylation  3.780717e-08
# 20  GO:0046133     pyrimidine ribonucleoside catabolic process  4.080519e-08
# 26  GO:0006703                   estrogen biosynthetic process  9.438592e-08
# 29  GO:0045916    negative regulation of complement activation  1.792544e-07
# 35  GO:0033081  regulation of T cell differentiation in thymus  5.234933e-07
# 40  GO:0002921  negative regulation of humoral immune response  7.788734e-07
# 47  GO:0006369  termination of RNA polymerase II transcription  1.373182e-06
# 48  GO:0008334                  histone mRNA metabolic process  1.448484e-06
# 66  GO:0006749                   glutathione metabolic process  4.592398e-06
# 71  GO:0010955       negative regulation of protein processing  5.448677e-06
#
#        BFold
# 19  3.904828
# 20  6.249585
# 26  3.843655
# 29  4.370029
# 35  2.308571
# 40  3.955009
# 47  2.414571
# 48  2.745745
# 66  2.208914
# 71  2.330956

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenotype').head(10)
# Out:
#           # ID                                               Desc     BPval  \
# 26  MP:0001856                                        myocarditis  0.000003
# 34  MP:0001870                        salivary gland inflammation  0.000007
# 36  MP:0004041  increased susceptibility to kidney reperfusion...  0.000008
# 44  MP:0002389         abnormal Peyer's patch follicle morphology  0.000018
# 60  MP:0002392      abnormal Peyer's patch T cell area morphology  0.000067
# 62  MP:0008862                                   asymmetric snout  0.000070
# 68  MP:0003452                  abnormal parotid gland morphology  0.000087
# 69  MP:0003407       abnormal central nervous system regeneration  0.000088
# 72  MP:0009488           abnormal pancreatic islet cell apoptosis  0.000095
# 88  MP:0002565                            delayed circadian phase  0.000161
#
#        BFold
# 26  2.899189
# 34  2.334535
# 36  4.074445
# 44  2.146357
# 60  3.541650
# 62  2.759692
# 68  3.455479
# 69  2.634864
# 72  3.107736
# 88  2.458035

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenoSingleKO').head(10)
# Out:
#           # ID                                               Desc     BPval  \
# 24  MP:0001856                                        myocarditis  0.000003
# 29  MP:0004041  increased susceptibility to kidney reperfusion...  0.000008
# 35  MP:0008126                    increased dendritic cell number  0.000017
# 59  MP:0008862                                   asymmetric snout  0.000070
# 63  MP:0003452                  abnormal parotid gland morphology  0.000087
# 64  MP:0001870                        salivary gland inflammation  0.000092
# 65  MP:0003031                                           acidosis  0.000095
# 81  MP:0002565                            delayed circadian phase  0.000161
# 84  MP:0000786  abnormal embryonic neuroepithelial layer diffe...  0.000176
# 86  MP:0002389         abnormal Peyer's patch follicle morphology  0.000194
#
#        BFold
# 24  3.121352
# 29  4.074445
# 35  2.882200
# 59  2.759692
# 63  3.455479
# 64  2.225581
# 65  2.154495
# 81  2.458035
# 84  2.571348
# 86  2.095309

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOCellularComponent').head(10)
# Out:
#           # ID                                               Desc  \
# 4   GO:0042611                                MHC protein complex
# 17  GO:0071556  integral to lumenal side of endoplasmic reticu...
# 20  GO:0042612                        MHC class I protein complex
# 21  GO:0042613                       MHC class II protein complex
# 26  GO:0005761                             mitochondrial ribosome
# 28  GO:0012507             ER to Golgi transport vesicle membrane
# 32  GO:0005763              mitochondrial small ribosomal subunit
# 33  GO:0005689                      U12-type spliceosomal complex
# 36  GO:0005683                                           U7 snRNP
# 43  GO:0000421                        autophagic vacuole membrane
#
#            BPval     BFold
# 4   1.528314e-09  4.026781
# 17  5.172804e-06  3.113123
# 20  9.299293e-06  3.610470
# 21  2.079056e-05  3.733819
# 26  4.195153e-05  2.000761
# 28  5.810453e-05  2.100427
# 32  1.794133e-04  2.642842
# 33  2.281263e-04  2.342155
# 36  3.130327e-04  3.936596
# 43  6.123051e-04  2.136283

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOMolecularFunction').head(10)
# Out:
#           # ID                                               Desc  \
# 0   GO:0004303           estradiol 17-beta-dehydrogenase activity
# 1   GO:0003823                                    antigen binding
# 2   GO:0001848                                 complement binding
# 3   GO:0033764  steroid dehydrogenase activity, acting on the ...
# 5   GO:0016755  transferase activity, transferring amino-acyl ...
# 6   GO:0032395                     MHC class II receptor activity
# 8   GO:0042605                            peptide antigen binding
# 10  GO:0003746             translation elongation factor activity
# 11  GO:0016229                     steroid dehydrogenase activity
# 14  GO:0017091                            AU-rich element binding
#
#            BPval     BFold
# 0   5.508480e-09  4.707856
# 1   2.894243e-08  2.479716
# 2   6.373650e-08  5.244508
# 3   3.355615e-07  2.687094
# 5   1.664452e-06  2.462163
# 6   3.954467e-06  4.956089
# 8   5.772647e-06  3.000111
# 10  8.282372e-06  2.717842
# 11  1.135737e-05  2.281044
# 14  1.549784e-05  2.895299

# %% [markdown]
# #### PC5 (the second component)

# %%
component_idx=5

# %% [markdown]
# #### what assays are driving this component?

# %%
np.argsort(-u_dot_d_find_assay[:, component_idx])[:5]
# Out:
# array([188, 433,  76, 434, 431])

# %%
u_dot_d_find_assay[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], component_idx]
# Out:
# array([0.1195496 , 0.08228496, 0.05328201, 0.03843322, 0.03278715])

# %%
metadata.iloc[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], :]
# Out:
#     sample_number antibody Genome assembly   Antigen class       Antigen  \
# 188    SRX1027619      NaN            hg19  No description           NaN
# 433     SRX651491      NaN            hg19         Histone       H3K4me3
# 76      ERX329687      NaN            hg19    Unclassified  Unclassified
# 434     SRX651492      NaN            hg19         Histone       H3K4me1
# 431     SRX651470      NaN            hg19         Histone       H3K4me3
#
#     Cell type class                 Cell type  \
# 188           Blood  Lymphoblastoid cell line
# 433           Blood  Lymphoblastoid cell line
# 76            Blood  Lymphoblastoid cell line
# 434           Blood  Lymphoblastoid cell line
# 431           Blood  Lymphoblastoid cell line
#
#                                  Cell type description  \
# 188  Tissue=blood|Lineage=mesoderm|Description=pare...
# 433  Tissue=blood|Lineage=mesoderm|Description=pare...
# 76   Tissue=blood|Lineage=mesoderm|Description=pare...
# 434  Tissue=blood|Lineage=mesoderm|Description=pare...
# 431  Tissue=blood|Lineage=mesoderm|Description=pare...
#
#                 Processing logs  \
# 188  804451442,97.3,44.1,118575
# 433    166047212,93.9,6.4,63296
# 76   238094924,94.2,33.9,144042
# 434   112405175,94.2,1.6,121976
# 431    117212731,95.4,4.0,47422
#
#                                                  Title  \
# 188                  ChIP-seq of Homo sapiens: H3K4me3
# 433  GSM1435515: LCL19238 H3K4me3; Homo sapiens; Ch...
# 76   Illumina HiSeq 2000 sequencing; Coordinated ef...
# 434  GSM1435516: LCL19239 H3K4me1; Homo sapiens; Ch...
# 431  GSM1435517: LCL19239 H3K4me3; Homo sapiens; Ch...
#
#               ...           age  treatment genotype lab  age.1 health state  \
# 188           ...           NaN        NaN      NaN NaN    NaN          NaN
# 433           ...           NaN        NaN      NaN NaN    NaN          NaN
# 76            ...           NaN        NaN      NaN NaN    NaN          NaN
# 434           ...           NaN        NaN      NaN NaN    NaN          NaN
# 431           ...           NaN        NaN      NaN NaN    NaN          NaN
#
#      cell_type  tissue_type  provider                     sex
# 188       LCLs        blood   Coriell  pooled male and female
# 433        NaN          NaN       NaN                     NaN
# 76     NA12878          NaN       NaN                  female
# 434        NaN          NaN       NaN                     NaN
# 431        NaN          NaN       NaN                     NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# #### what genomic bins are driving this component?

# %%
np.argsort(-v_dot_d_find_loci[:, component_idx])[:5]
# Out:
# array([282969, 130825, 187463, 337732, 233484])

# %%
v_dot_d_find_loci[np.argsort(-v_dot_d_find_loci[:, component_idx])[:5], component_idx]
# Out:
# array([8.04405926e-05, 6.46164381e-05, 6.45142013e-05, 6.39899652e-05,
#        6.37951179e-05])

# %% [markdown]
# #### where is our loci of interest in this ranking?

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[genomic_bin_idx, component_idx])
# Out:
# 10884

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[genomic_bin_idx, component_idx]) / v_dot_d_find_loci.shape[0]
# Out:
# 0.028676743751004503

# %% [markdown]
# It's roughly on the top 3 percentile.

# %% [markdown]
# #### results of the enrichment analysis

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'HumanPhenotypeOntology').head(10)
# Out:
#           # ID                                 Desc         BPval     BFold
# 0   HP:0002697                    Parietal foramina  4.367679e-08  2.372433
# 1   HP:0004425                        Flat forehead  1.568965e-06  2.735910
# 3   HP:0004442            Sagittal craniosynostosis  2.359962e-06  2.733096
# 4   HP:0002365          Hypoplasia of the brainstem  2.396735e-06  2.031767
# 5   HP:0010054  Abnormality of the first metatarsal  2.506458e-06  2.574793
# 7   HP:0006191                   Deep palmar crease  4.189624e-06  2.977180
# 8   HP:0000557                          Buphthalmos  4.706791e-06  2.287392
# 12  HP:0009836       Broad distal phalanx of finger  1.739019e-05  2.601329
# 18  HP:0003741        Congenital muscular dystrophy  3.098136e-05  2.094681
# 21  HP:0003535          3-Methylglutaconic aciduria  3.861840e-05  2.428799

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOBiologicalProcess').head(10)
# Out:
#            # ID                                               Desc     BPval  \
# 62   GO:0035089        establishment of apical/basal cell polarity  0.000008
# 76   GO:0075733                   intracellular transport of virus  0.000012
# 100  GO:0051775                            response to redox state  0.000021
# 108  GO:0061162           establishment of monopolar cell polarity  0.000025
# 113  GO:0070127  tRNA aminoacylation for mitochondrial protein ...  0.000027
# 116  GO:0071624      positive regulation of granulocyte chemotaxis  0.000029
# 126  GO:0090023       positive regulation of neutrophil chemotaxis  0.000034
# 148  GO:0018401  peptidyl-proline hydroxylation to 4-hydroxy-L-...  0.000056
# 161  GO:0001672    regulation of chromatin assembly or disassembly  0.000072
# 164  GO:0006999                          nuclear pore organization  0.000077
#
#         BFold
# 62   2.658500
# 76   2.073909
# 100  2.764178
# 108  2.320837
# 113  4.115960
# 116  2.016287
# 126  2.020100
# 148  2.373342
# 161  3.185283
# 164  2.528835

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenotype').head(10)
# Out:
#           # ID                                        Desc         BPval  \
# 12  MP:0001771        abnormal circulating magnesium level  1.832349e-07
# 19  MP:0003954     abnormal Reichert's membrane morphology  8.388949e-07
# 53  MP:0002348      abnormal lymph node medulla morphology  9.682417e-06
# 54  MP:0010092       increased circulating magnesium level  1.018919e-05
# 59  MP:0009545  abnormal dermis papillary layer morphology  1.604188e-05
# 60  MP:0010743                      delayed suture closure  1.697130e-05
# 65  MP:0001669                 abnormal glucose absorption  2.245532e-05
# 69  MP:0006210                         abnormal orbit size  2.804297e-05
# 77  MP:0002050                            pheochromocytoma  3.830129e-05
# 79  MP:0000666        decreased prostate gland duct number  4.319200e-05
#
#        BFold
# 12  2.327122
# 19  2.004437
# 53  2.903855
# 54  2.628006
# 59  2.274394
# 60  2.208579
# 65  2.618271
# 69  2.181630
# 77  2.589431
# 79  2.700373

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenoSingleKO').head(10)
# Out:
#           # ID                                        Desc         BPval  \
# 5   MP:0012129             failure of blastocyst formation  2.360537e-09
# 8   MP:0002663                  failure to form blastocele  3.603307e-09
# 23  MP:0003954     abnormal Reichert's membrane morphology  8.388949e-07
# 24  MP:0001771        abnormal circulating magnesium level  1.211860e-06
# 33  MP:0010743                      delayed suture closure  3.083532e-06
# 34  MP:0002050                            pheochromocytoma  3.483130e-06
# 44  MP:0002348      abnormal lymph node medulla morphology  9.682417e-06
# 48  MP:0009545  abnormal dermis papillary layer morphology  1.604188e-05
# 60  MP:0000275                           heart hyperplasia  4.592075e-05
# 69  MP:0002031     increased adrenal gland tumor incidence  6.052274e-05
#
#        BFold
# 5   2.005173
# 8   2.004262
# 23  2.004437
# 24  2.284786
# 33  2.694599
# 34  3.010810
# 44  2.903855
# 48  2.274394
# 60  2.012848
# 69  2.408676

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOCellularComponent').head(10)
# Out:
#           # ID                                               Desc     BPval  \
# 5   GO:0005606                                  laminin-1 complex  0.000001
# 7   GO:0043256                                    laminin complex  0.000005
# 21  GO:0019031                                     viral envelope  0.000610
# 48  GO:0031080                            nuclear pore outer ring  0.002727
# 54  GO:0005666            DNA-directed RNA polymerase III complex  0.004041
# 58  GO:0019908  nuclear cyclin-dependent protein kinase holoen...  0.004746
# 72  GO:0016461                      unconventional myosin complex  0.007764
# 81  GO:0005677                        chromatin silencing complex  0.010734
# 85  GO:0005736              DNA-directed RNA polymerase I complex  0.011807
# 93  GO:0005851  eukaryotic translation initiation factor 2B co...  0.014343
#
#        BFold
# 5   2.325389
# 7   2.148635
# 21  2.839336
# 48  2.255517
# 54  2.228519
# 58  2.188418
# 72  2.067299
# 81  2.111160
# 85  2.494752
# 93  2.793472

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOMolecularFunction').head(10)
# Out:
#           # ID                                               Desc  \
# 3   GO:0043022                                   ribosome binding
# 11  GO:0031545            peptidyl-proline 4-dioxygenase activity
# 14  GO:0043208                          glycosphingolipid binding
# 30  GO:0001056                        RNA polymerase III activity
# 34  GO:0005007  fibroblast growth factor-activated receptor ac...
# 48  GO:0032407                          MutSalpha complex binding
# 60  GO:0015377                 cation:chloride symporter activity
# 65  GO:0047499      calcium-independent phospholipase A2 activity
# 69  GO:0032404                    mismatch repair complex binding
# 74  GO:0016421                           CoA carboxylase activity
#
#            BPval     BFold
# 3   7.584495e-08  2.351977
# 11  8.138740e-06  2.466700
# 14  2.462545e-05  2.495340
# 30  3.860479e-04  3.131341
# 34  5.214530e-04  2.250279
# 48  1.512241e-03  2.575431
# 60  2.143232e-03  2.088132
# 65  2.303207e-03  3.545742
# 69  2.498749e-03  2.155177
# 74  2.932712e-03  2.029746

# %% [markdown]
# #### PC2 (the thrird component)

# %%
component_idx=2

# %% [markdown]
# #### what assays are driving this component?

# %%
np.argsort(-u_dot_d_find_assay[:, component_idx])[:5]
# Out:
# array([305, 366, 336, 321, 351])

# %%
u_dot_d_find_assay[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], component_idx]
# Out:
# array([0.0767717 , 0.07214937, 0.06740654, 0.05664575, 0.04790769])

# %%
metadata.iloc[np.argsort(-u_dot_d_find_assay[:, component_idx])[:5], :]
# Out:
#     sample_number antibody Genome assembly   Antigen class Antigen  \
# 305     SRX356559      sa1            hg19  TFs and others   STAG1
# 366     SRX356783      sa1            hg19  TFs and others   STAG1
# 336     SRX356747      sa1            hg19  TFs and others   STAG1
# 321     SRX356729      sa1            hg19  TFs and others   STAG1
# 351     SRX356765      sa1            hg19  TFs and others   STAG1
#
#     Cell type class                 Cell type  \
# 305           Blood  Lymphoblastoid cell line
# 366           Blood  Lymphoblastoid cell line
# 336           Blood  Lymphoblastoid cell line
# 321           Blood  Lymphoblastoid cell line
# 351           Blood  Lymphoblastoid cell line
#
#                                  Cell type description  \
# 305  Tissue=blood|Lineage=mesoderm|Description=pare...
# 366  Tissue=blood|Lineage=mesoderm|Description=pare...
# 336  Tissue=blood|Lineage=mesoderm|Description=pare...
# 321  Tissue=blood|Lineage=mesoderm|Description=pare...
# 351  Tissue=blood|Lineage=mesoderm|Description=pare...
#
#               Processing logs  \
# 305  30569210,98.7,45.3,46902
# 366  39045039,98.3,44.9,50318
# 336  33660922,97.3,43.8,47950
# 321  32218948,97.4,46.1,42241
# 351  28293163,97.6,37.8,45107
#
#                                                  Title ...  age  treatment  \
# 305  GSM1233991: GM18486 SA1 1; Homo sapiens; ChIP-Seq ...  NaN        NaN
# 366   GSM1234215: GM2630 SA1 2; Homo sapiens; ChIP-Seq ...  NaN        NaN
# 336   GSM1234179: GM2588 SA1 2; Homo sapiens; ChIP-Seq ...  NaN        NaN
# 321   GSM1234161: GM2255 SA1 2; Homo sapiens; ChIP-Seq ...  NaN        NaN
# 351   GSM1234197: GM2610 SA1 2; Homo sapiens; ChIP-Seq ...  NaN        NaN
#
#     genotype lab  age.1 health state  cell_type  tissue_type  provider  sex
# 305      NaN NaN    NaN          NaN      18486          NaN       NaN  NaN
# 366      NaN NaN    NaN          NaN       2630          NaN       NaN  NaN
# 336      NaN NaN    NaN          NaN       2588          NaN       NaN  NaN
# 321      NaN NaN    NaN          NaN       2255          NaN       NaN  NaN
# 351      NaN NaN    NaN          NaN       2610          NaN       NaN  NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# #### what genomic bins are driving this component?

# %%
np.argsort(-v_dot_d_find_loci[:, component_idx])[:5]
# Out:
# array([298320, 298321,  54352, 114709,  46679])

# %%
v_dot_d_find_loci[np.argsort(-v_dot_d_find_loci[:, component_idx])[:5], component_idx]
# Out:
# array([4.89963650e-05, 4.77846741e-05, 4.77053255e-05, 4.73716488e-05,
#        4.72138889e-05])

# %% [markdown]
# #### where is our loci of interest, chr17_38023 (index: 328517), in this ranking?

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[genomic_bin_idx, component_idx])
# Out:
# 48874

# %%
np.sum(v_dot_d_find_loci[:, component_idx] >= v_dot_d_find_loci[genomic_bin_idx, component_idx]) / v_dot_d_find_loci.shape[0]
# Out:
# 0.12877133168748567

# %% [markdown]
# It's roughly on the top 13 percentile.

# %% [markdown]
# #### results of the enrichment analysis

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'HumanPhenotypeOntology').head(10)
# Out:
#           # ID                                     Desc         BPval  \
# 8   HP:0012103         Abnormality of the mitochondrion  1.981297e-08
# 11  HP:0003287  Abnormality of mitochondrial metabolism  5.547277e-08
# 16  HP:0010972          Anemia of inadequate production  1.467984e-07
# 20  HP:0200042                               Skin ulcer  2.149489e-07
# 22  HP:0001581                Recurrent skin infections  3.267830e-07
# 23  HP:0002665                                 Lymphoma  3.357733e-07
# 27  HP:0005406      Recurrent bacterial skin infections  4.352149e-07
# 37  HP:0006429                       Broad femoral neck  2.049863e-06
# 38  HP:0002722              Recurrent abscess formation  2.050315e-06
# 43  HP:0001733                             Pancreatitis  3.059544e-06
#
#        BFold
# 8   2.430178
# 11  2.397021
# 16  2.084019
# 20  2.021010
# 22  2.644626
# 23  2.074043
# 27  4.113836
# 37  7.213434
# 38  3.547911
# 43  2.464570

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOBiologicalProcess').head(10)
# Out:
#           # ID                                               Desc  \
# 30  GO:0060333        interferon-gamma-mediated signaling pathway
# 39  GO:0045047                            protein targeting to ER
# 44  GO:0071346              cellular response to interferon-gamma
# 45  GO:0038096  Fc-gamma receptor signaling pathway involved i...
# 47  GO:0002431  Fc receptor mediated stimulatory signaling pat...
# 48  GO:0038094                Fc-gamma receptor signaling pathway
# 57  GO:0072599  establishment of protein localization to endop...
# 60  GO:0006614  SRP-dependent cotranslational protein targetin...
# 65  GO:0015740                         C4-dicarboxylate transport
# 67  GO:0006613      cotranslational protein targeting to membrane
#
#            BPval     BFold
# 30  9.010372e-11  2.559231
# 39  3.183959e-10  2.280882
# 44  5.468346e-10  2.159660
# 45  5.472179e-10  2.147846
# 47  5.672283e-10  2.146109
# 48  5.772810e-10  2.145260
# 57  2.336302e-09  2.173245
# 60  3.810641e-09  2.247171
# 65  7.328115e-09  4.436732
# 67  8.225698e-09  2.201283

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenotype').head(10)
# Out:
#           # ID                                      Desc         BPval  \
# 17  MP:0005153             abnormal B cell proliferation  3.181409e-20
# 21  MP:0008217                abnormal B cell activation  3.436036e-18
# 37  MP:0005093            decreased B cell proliferation  7.882232e-15
# 41  MP:0008180  abnormal marginal zone B cell morphology  2.404651e-14
# 45  MP:0008495                      decreased IgG1 level  9.733961e-14
# 46  MP:0001806                       decreased IgM level  1.530640e-13
# 50  MP:0002362  abnormal spleen marginal zone morphology  4.167194e-13
# 56  MP:0008182     decreased marginal zone B cell number  1.844706e-12
# 68  MP:0005154            increased B cell proliferation  1.483511e-10
# 92  MP:0003303                   peritoneal inflammation  1.156149e-08
#
#        BFold
# 17  2.120136
# 21  2.012082
# 37  2.142833
# 41  2.229240
# 45  2.015448
# 46  2.108597
# 50  2.034597
# 56  2.315187
# 68  2.424640
# 92  3.763917

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'MGIPhenoSingleKO').head(10)
# Out:
#           # ID                                         Desc         BPval  \
# 29  MP:0005153                abnormal B cell proliferation  2.973987e-14
# 40  MP:0005461           abnormal dendritic cell morphology  1.445606e-12
# 42  MP:0001806                          decreased IgM level  3.291375e-12
# 53  MP:0005093               decreased B cell proliferation  1.718479e-10
# 70  MP:0002418  increased susceptibility to viral infection  8.788483e-09
# 72  MP:0000921                                demyelination  1.427529e-08
# 74  MP:0008125               abnormal dendritic cell number  1.474424e-08
# 76  MP:0008088     abnormal T-helper 1 cell differentiation  2.115314e-08
# 77  MP:0003303                      peritoneal inflammation  2.189665e-08
# 82  MP:0005154               increased B cell proliferation  4.557809e-08
#
#        BFold
# 29  2.068460
# 40  2.379902
# 42  2.209544
# 53  2.145825
# 70  2.034574
# 72  2.140232
# 74  2.382514
# 76  3.146739
# 77  4.346423
# 82  2.279219

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOCellularComponent').head(10)
# Out:
#           # ID                                               Desc  \
# 9   GO:0005758                  mitochondrial intermembrane space
# 15  GO:0000307  cyclin-dependent protein kinase holoenzyme com...
# 20  GO:0000788                                 nuclear nucleosome
# 27  GO:0044798               nuclear transcription factor complex
# 31  GO:0031095            platelet dense tubular network membrane
# 32  GO:0000786                                         nucleosome
# 34  GO:0031094                     platelet dense tubular network
# 35  GO:0005826                        actomyosin contractile ring
# 39  GO:0005761                             mitochondrial ribosome
# 40  GO:0090544                                   BAF-type complex
#
#            BPval     BFold
# 9   4.658954e-08  2.924884
# 15  1.661690e-06  2.979384
# 20  3.649093e-06  6.005715
# 27  1.326775e-05  2.009501
# 31  2.117509e-05  3.726373
# 32  2.948377e-05  2.232604
# 34  6.315071e-05  3.377614
# 35  6.359909e-05  4.808933
# 39  1.168505e-04  2.227518
# 40  1.311371e-04  2.334366

# %%
read_great_res_wrapper(enrichment_data_dir, component_idx, 'GOMolecularFunction').head(10)
# Out:
#           # ID                                               Desc  \
# 4   GO:0008140      cAMP response element binding protein binding
# 9   GO:0035673    oligopeptide transmembrane transporter activity
# 11  GO:0015198                  oligopeptide transporter activity
# 13  GO:0004715  non-membrane spanning protein tyrosine kinase ...
# 15  GO:0005313     L-glutamate transmembrane transporter activity
# 16  GO:0015197                       peptide transporter activity
# 17  GO:0015556  C4-dicarboxylate transmembrane transporter act...
# 19  GO:0005310  dicarboxylic acid transmembrane transporter ac...
# 21  GO:0005154           epidermal growth factor receptor binding
# 23  GO:0031996                               thioesterase binding
#
#            BPval     BFold
# 4   2.734837e-09  6.534605
# 9   1.666693e-08  7.323736
# 11  1.119388e-07  6.256376
# 13  4.323711e-07  2.190691
# 15  6.843716e-07  3.050932
# 16  7.138872e-07  4.969029
# 17  7.730462e-07  5.308462
# 19  1.089172e-06  2.631758
# 21  1.510183e-06  2.286666
# 23  1.584143e-06  3.249673
